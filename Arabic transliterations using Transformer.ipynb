# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import os
# %matplotlib inline
sns.set()
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split
import re
import time

# %%
from text import Alphabet,levenshtein, wer, cer
from transformer import Transformer, CustomSchedule, evaluate ,accuracy_function

# %%
#  Create Alphabet object for languages to convert from text to labels and vice versa
alphabet_ar = Alphabet('alphabet_ar_ANETAC.txt')
alphabet_en = Alphabet('alphabet_en_ANETAC.txt')

# %%
# df_ar=pd.read_csv('EN-AR Translit/train.ar',names=['arabic'],header=None)
# df_en=pd.read_csv('EN-AR Translit/train.en',names=['english'],header=None)

# df_ar_val=pd.read_csv('EN-AR Translit/dev.ar',names=['arabic'],header=None)
# df_en_val=pd.read_csv('EN-AR Translit/dev.en',names=['english'],header=None)

# df1=pd.concat([df_ar,df_en],axis=1)
# df2=pd.concat([df_ar_val,df_en_val],axis=1)
# df3=pd.read_excel('transliterations_ar2en.xlsx')
# df=pd.concat([df1,df2,df3],axis=0)

# %%
# Read SAS dataset 
df = pd.read_excel('transliterations_ar2en.xlsx')

# %%
df.head()
# Out:
#   arabic english
# 0     آب      AB
# 1    آبي     ABE
# 2    آتي     ATI
# 3   آثار   AASER
# 4    آدم    ADAM

# %%
# add start and end token for arabic and english samples
df['arabic'] = df['arabic'].apply(lambda x : '<'+ x +'>')
df['english'] = df['english'].apply(lambda x : '<'+ str(x).lower()+'>')

# %%
#  remove the tashkeel in the arabic text
noise = re.compile(""" ّ    | # Tashdid
َ    | # Fatha
ً    | # Tanwin Fath
ُ    | # Damma
ٌ    | # Tanwin Damm
ِ    | # Kasra
ٍ    | # Tanwin Kasr
ْ    | # Sukun
ـ     # Tatwil/Kashida
""", re.VERBOSE)
df['arabic_encoded'] = df['arabic'].apply(lambda x : alphabet_ar.encode(re.sub(noise, '',x)))
df['english_encoded'] = df['english'].apply(lambda x : alphabet_en.encode(x))

# %% [markdown]
# ## Set hyperparameters

# %%
BUFFER_SIZE = 20000
BATCH_SIZE = 16

embedding_dim = 32
units = 128
n, d = 64, 64   #n, d = 256, 128
num_layers = 2
d_model = 64
dff = 64
num_heads = 2
dropout_rate = 0.3

vocab_inp_size = alphabet_ar.size()+1
vocab_tar_size = alphabet_en.size()+1

checkpoint_path = "./checkpoints/train4"

# %%
#  function to encode the text to tensorflow tensor.
def encode(txt_ar,txt_en):
  text = re.sub(noise, '', txt_ar.numpy().decode('utf8'))
  ar=tf.convert_to_tensor(alphabet_ar.encode(text),dtype=tf.int64)
  en=tf.convert_to_tensor(alphabet_en.encode(txt_en.numpy().decode('utf8')),dtype=tf.int64)
  return ar,en
#  Wraps a python function into a TensorFlow op that executes it eagerly.  
def tf_encode(txt_ar, txt_en):
    result_ar, result_en = tf.py_function(encode, [txt_ar, txt_en], [tf.int64, tf.int64])
    return result_ar, result_en

# create tensorflow dataset
dataset = tf.data.Dataset.from_tensor_slices((np.array(df['arabic'].values),np.array(df['english'].values)))
dataset = dataset.map(tf_encode, num_parallel_calls=tf.data.experimental.AUTOTUNE)
dataset = dataset.shuffle(BUFFER_SIZE).padded_batch(BATCH_SIZE, padded_shapes=([None], [None]))
dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## Optimizer

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                     epsilon=1e-9)

# %% [markdown]
# ## Loss and metrics

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask
  
  return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# %% [markdown]
# ## Training and checkpointing

# %%
# initialize the model
transformer = Transformer(
    num_layers=num_layers,
    d_model=d_model,
    num_heads=num_heads,
    dff=dff,
    input_vocab_size=alphabet_ar.size()+1,
    target_vocab_size=alphabet_en.size()+1, 
    pe_input=50, 
    pe_target=50,
    rate=dropout_rate)

# %% [markdown]
# ### Checkpointing

# %% [markdown]
# Create the checkpoint path and the checkpoint manager. This will be used to save checkpoints every `n` epochs.

# %%
ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
  ckpt.restore(ckpt_manager.latest_checkpoint)
  print ('Latest checkpoint restored!!')

# %%
EPOCHS = 30

# %%
# The @tf.function trace-compiles train_step into a TF graph for faster
# execution. The function specializes to the precise shape of the argument
# tensors. To avoid re-tracing due to the variable sequence lengths or variable
# batch sizes (the last batch is smaller), use input_signature to specify
# more generic shapes.

train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
]

@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
  tar_inp = tar[:, :-1]
  tar_real = tar[:, 1:]
  
  enc_padding_mask, combined_mask, dec_padding_mask = create_masks(inp, tar_inp)
  
  with tf.GradientTape() as tape:
    predictions, _ = transformer(inp, tar_inp, 
                                 True, 
                                 enc_padding_mask, 
                                 combined_mask, 
                                 dec_padding_mask)
    loss = loss_function(tar_real, predictions)

  gradients = tape.gradient(loss, transformer.trainable_variables)    
  optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))
  
  train_loss(loss)
  train_accuracy(accuracy_function(tar_real, predictions))

# %% [markdown]
# ### Training Loop

# %%
for epoch in range(EPOCHS):
  start = time.time()
  
  train_loss.reset_states()
  train_accuracy.reset_states()
  
  # inp -> portuguese, tar -> english
  for (batch, (inp, tar)) in enumerate(dataset):
    train_step(inp, tar)
    
    if batch % 50 == 0:
      print(f'Epoch {epoch + 1} Batch {batch} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')
      
  if (epoch + 1) % 5 == 0:
    ckpt_save_path = ckpt_manager.save()
    print (f'Saving checkpoint for epoch {epoch+1} at {ckpt_save_path}')
    
  print(f'Epoch {epoch + 1} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

  print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
# Out:
# Epoch 1 Batch 0 Loss 4.2024 Accuracy 0.0388
# Epoch 1 Batch 50 Loss 4.0718 Accuracy 0.0376
# Epoch 1 Batch 100 Loss 3.8440 Accuracy 0.0772
# Epoch 1 Batch 150 Loss 3.6582 Accuracy 0.1056
# Epoch 1 Batch 200 Loss 3.5205 Accuracy 0.1208
# Epoch 1 Batch 250 Loss 3.4173 Accuracy 0.1317
# Epoch 1 Batch 300 Loss 3.3297 Accuracy 0.1431
# Epoch 1 Batch 350 Loss 3.2594 Accuracy 0.1537
# Epoch 1 Batch 400 Loss 3.1917 Accuracy 0.1659
# Epoch 1 Batch 450 Loss 3.1284 Accuracy 0.1790
# Epoch 1 Batch 500 Loss 3.0738 Accuracy 0.1908
# Epoch 1 Batch 550 Loss 3.0196 Accuracy 0.2021
# Epoch 1 Batch 600 Loss 2.9684 Accuracy 0.2132
# Epoch 1 Batch 650 Loss 2.9229 Accuracy 0.2221
# Epoch 1 Batch 700 Loss 2.8823 Accuracy 0.2298
# Epoch 1 Batch 750 Loss 2.8440 Accuracy 0.2366
# Epoch 1 Batch 800 Loss 2.8048 Accuracy 0.2439
# Epoch 1 Batch 850 Loss 2.7716 Accuracy 0.2501
# Epoch 1 Batch 900 Loss 2.7384 Accuracy 0.2560
# Epoch 1 Batch 950 Loss 2.7080 Accuracy 0.2612
# Epoch 1 Batch 1000 Loss 2.6801 Accuracy 0.2663
# Epoch 1 Batch 1050 Loss 2.6521 Accuracy 0.2718
# Epoch 1 Batch 1100 Loss 2.6248 Accuracy 0.2767
# Epoch 1 Batch 1150 Loss 2.5965 Accuracy 0.2822
# Epoch 1 Batch 1200 Loss 2.5689 Accuracy 0.2880
# Epoch 1 Batch 1250 Loss 2.5435 Accuracy 0.2928
# Epoch 1 Batch 1300 Loss 2.5161 Accuracy 0.2984
# Epoch 1 Batch 1350 Loss 2.4902 Accuracy 0.3035
# Epoch 1 Batch 1400 Loss 2.4647 Accuracy 0.3094
# Epoch 1 Batch 1450 Loss 2.4396 Accuracy 0.3148
# Epoch 1 Batch 1500 Loss 2.4153 Accuracy 0.3201
# Epoch 1 Batch 1550 Loss 2.3913 Accuracy 0.3257
# Epoch 1 Batch 1600 Loss 2.3676 Accuracy 0.3313
# Epoch 1 Batch 1650 Loss 2.3444 Accuracy 0.3363
# Epoch 1 Batch 1700 Loss 2.3218 Accuracy 0.3413
# Epoch 1 Batch 1750 Loss 2.2997 Accuracy 0.3464
# Epoch 1 Batch 1800 Loss 2.2775 Accuracy 0.3515
# Epoch 1 Batch 1850 Loss 2.2570 Accuracy 0.3561
# Epoch 1 Batch 1900 Loss 2.2359 Accuracy 0.3610
# Epoch 1 Batch 1950 Loss 2.2145 Accuracy 0.3662
# Epoch 1 Batch 2000 Loss 2.1942 Accuracy 0.3710
# Epoch 1 Batch 2050 Loss 2.1741 Accuracy 0.3758
# Epoch 1 Batch 2100 Loss 2.1549 Accuracy 0.3805
# Epoch 1 Batch 2150 Loss 2.1353 Accuracy 0.3852
# Epoch 1 Batch 2200 Loss 2.1167 Accuracy 0.3897
# Epoch 1 Batch 2250 Loss 2.0987 Accuracy 0.3939
# Epoch 1 Batch 2300 Loss 2.0813 Accuracy 0.3981
# Epoch 1 Batch 2350 Loss 2.0642 Accuracy 0.4022
# Epoch 1 Batch 2400 Loss 2.0479 Accuracy 0.4060
# Epoch 1 Batch 2450 Loss 2.0316 Accuracy 0.4100
# Epoch 1 Batch 2500 Loss 2.0163 Accuracy 0.4138
# Epoch 1 Batch 2550 Loss 2.0004 Accuracy 0.4176
# Epoch 1 Batch 2600 Loss 1.9851 Accuracy 0.4214
# Epoch 1 Batch 2650 Loss 1.9701 Accuracy 0.4251
# Epoch 1 Batch 2700 Loss 1.9557 Accuracy 0.4286
# Epoch 1 Batch 2750 Loss 1.9419 Accuracy 0.4321
# Epoch 1 Batch 2800 Loss 1.9285 Accuracy 0.4355
# Epoch 1 Batch 2850 Loss 1.9158 Accuracy 0.4386
# Epoch 1 Batch 2900 Loss 1.9025 Accuracy 0.4419
# Epoch 1 Batch 2950 Loss 1.8899 Accuracy 0.4450
# Epoch 1 Batch 3000 Loss 1.8769 Accuracy 0.4482
# Epoch 1 Batch 3050 Loss 1.8646 Accuracy 0.4511
# Epoch 1 Batch 3100 Loss 1.8527 Accuracy 0.4541
# Epoch 1 Batch 3150 Loss 1.8408 Accuracy 0.4570
# Epoch 1 Batch 3200 Loss 1.8296 Accuracy 0.4599
# Epoch 1 Batch 3250 Loss 1.8189 Accuracy 0.4625
# Epoch 1 Batch 3300 Loss 1.8081 Accuracy 0.4653
# Epoch 1 Batch 3350 Loss 1.7977 Accuracy 0.4677
# Epoch 1 Batch 3400 Loss 1.7876 Accuracy 0.4703
# Epoch 1 Loss 1.7797 Accuracy 0.4723
# Time taken for 1 epoch: 84.97 secs
#
# Epoch 2 Batch 0 Loss 1.2496 Accuracy 0.5603
# Epoch 2 Batch 50 Loss 1.1694 Accuracy 0.6195
# Epoch 2 Batch 100 Loss 1.1236 Accuracy 0.6353
# Epoch 2 Batch 150 Loss 1.1089 Accuracy 0.6362
# Epoch 2 Batch 200 Loss 1.1026 Accuracy 0.6376
# Epoch 2 Batch 250 Loss 1.0958 Accuracy 0.6405
# Epoch 2 Batch 300 Loss 1.0854 Accuracy 0.6443
# Epoch 2 Batch 350 Loss 1.0810 Accuracy 0.6461
# Epoch 2 Batch 400 Loss 1.0776 Accuracy 0.6473
# Epoch 2 Batch 450 Loss 1.0738 Accuracy 0.6482
# Epoch 2 Batch 500 Loss 1.0679 Accuracy 0.6499
# Epoch 2 Batch 550 Loss 1.0639 Accuracy 0.6511
# Epoch 2 Batch 600 Loss 1.0601 Accuracy 0.6523
# Epoch 2 Batch 650 Loss 1.0604 Accuracy 0.6524
# Epoch 2 Batch 700 Loss 1.0584 Accuracy 0.6523
# Epoch 2 Batch 750 Loss 1.0563 Accuracy 0.6529
# Epoch 2 Batch 800 Loss 1.0530 Accuracy 0.6535
# Epoch 2 Batch 850 Loss 1.0508 Accuracy 0.6541
# Epoch 2 Batch 900 Loss 1.0474 Accuracy 0.6552
# Epoch 2 Batch 950 Loss 1.0456 Accuracy 0.6554
# Epoch 2 Batch 1000 Loss 1.0415 Accuracy 0.6567
# Epoch 2 Batch 1050 Loss 1.0390 Accuracy 0.6575
# Epoch 2 Batch 1100 Loss 1.0358 Accuracy 0.6583
# Epoch 2 Batch 1150 Loss 1.0340 Accuracy 0.6586
# Epoch 2 Batch 1200 Loss 1.0322 Accuracy 0.6590
# Epoch 2 Batch 1250 Loss 1.0306 Accuracy 0.6593
# Epoch 2 Batch 1300 Loss 1.0286 Accuracy 0.6599
# Epoch 2 Batch 1350 Loss 1.0255 Accuracy 0.6610
# Epoch 2 Batch 1400 Loss 1.0245 Accuracy 0.6614
# Epoch 2 Batch 1450 Loss 1.0224 Accuracy 0.6619
# Epoch 2 Batch 1500 Loss 1.0204 Accuracy 0.6626
# Epoch 2 Batch 1550 Loss 1.0176 Accuracy 0.6632
# Epoch 2 Batch 1600 Loss 1.0163 Accuracy 0.6635
# Epoch 2 Batch 1650 Loss 1.0162 Accuracy 0.6636
# Epoch 2 Batch 1700 Loss 1.0144 Accuracy 0.6640
# Epoch 2 Batch 1750 Loss 1.0125 Accuracy 0.6647
# Epoch 2 Batch 1800 Loss 1.0114 Accuracy 0.6649
# Epoch 2 Batch 1850 Loss 1.0102 Accuracy 0.6652
# Epoch 2 Batch 1900 Loss 1.0083 Accuracy 0.6656
# Epoch 2 Batch 1950 Loss 1.0063 Accuracy 0.6662
# Epoch 2 Batch 2000 Loss 1.0043 Accuracy 0.6665
# Epoch 2 Batch 2050 Loss 1.0028 Accuracy 0.6669
# Epoch 2 Batch 2100 Loss 1.0008 Accuracy 0.6674
# Epoch 2 Batch 2150 Loss 0.9992 Accuracy 0.6676
# Epoch 2 Batch 2200 Loss 0.9974 Accuracy 0.6679
# Epoch 2 Batch 2250 Loss 0.9960 Accuracy 0.6682
# Epoch 2 Batch 2300 Loss 0.9942 Accuracy 0.6687
# Epoch 2 Batch 2350 Loss 0.9930 Accuracy 0.6691
# Epoch 2 Batch 2400 Loss 0.9914 Accuracy 0.6695
# Epoch 2 Batch 2450 Loss 0.9896 Accuracy 0.6700
# Epoch 2 Batch 2500 Loss 0.9879 Accuracy 0.6704
# Epoch 2 Batch 2550 Loss 0.9867 Accuracy 0.6708
# Epoch 2 Batch 2600 Loss 0.9854 Accuracy 0.6712
# Epoch 2 Batch 2650 Loss 0.9842 Accuracy 0.6716
# Epoch 2 Batch 2700 Loss 0.9820 Accuracy 0.6721
# Epoch 2 Batch 2750 Loss 0.9804 Accuracy 0.6726
# Epoch 2 Batch 2800 Loss 0.9786 Accuracy 0.6731
# Epoch 2 Batch 2850 Loss 0.9771 Accuracy 0.6735
# Epoch 2 Batch 2900 Loss 0.9758 Accuracy 0.6738
# Epoch 2 Batch 2950 Loss 0.9746 Accuracy 0.6742
# Epoch 2 Batch 3000 Loss 0.9731 Accuracy 0.6745
# Epoch 2 Batch 3050 Loss 0.9711 Accuracy 0.6750
# Epoch 2 Batch 3100 Loss 0.9697 Accuracy 0.6756
# Epoch 2 Batch 3150 Loss 0.9686 Accuracy 0.6759
# Epoch 2 Batch 3200 Loss 0.9675 Accuracy 0.6762
# Epoch 2 Batch 3250 Loss 0.9661 Accuracy 0.6766
# Epoch 2 Batch 3300 Loss 0.9645 Accuracy 0.6770
# Epoch 2 Batch 3350 Loss 0.9632 Accuracy 0.6772
# Epoch 2 Batch 3400 Loss 0.9616 Accuracy 0.6776
# Epoch 2 Loss 0.9605 Accuracy 0.6779
# Time taken for 1 epoch: 74.50 secs
#
# Epoch 3 Batch 0 Loss 0.8971 Accuracy 0.7176
# Epoch 3 Batch 50 Loss 0.8579 Accuracy 0.7042
# Epoch 3 Batch 100 Loss 0.8664 Accuracy 0.7018
# Epoch 3 Batch 150 Loss 0.8687 Accuracy 0.7017
# Epoch 3 Batch 200 Loss 0.8595 Accuracy 0.7043
# Epoch 3 Batch 250 Loss 0.8520 Accuracy 0.7069
# Epoch 3 Batch 300 Loss 0.8448 Accuracy 0.7090
# Epoch 3 Batch 350 Loss 0.8388 Accuracy 0.7104
# Epoch 3 Batch 400 Loss 0.8389 Accuracy 0.7097
# Epoch 3 Batch 450 Loss 0.8373 Accuracy 0.7104
# Epoch 3 Batch 500 Loss 0.8353 Accuracy 0.7110
# Epoch 3 Batch 550 Loss 0.8345 Accuracy 0.7107
# Epoch 3 Batch 600 Loss 0.8333 Accuracy 0.7112
# Epoch 3 Batch 650 Loss 0.8317 Accuracy 0.7116
# Epoch 3 Batch 700 Loss 0.8314 Accuracy 0.7112
# Epoch 3 Batch 750 Loss 0.8305 Accuracy 0.7108
# Epoch 3 Batch 800 Loss 0.8297 Accuracy 0.7112
# Epoch 3 Batch 850 Loss 0.8286 Accuracy 0.7114
# Epoch 3 Batch 900 Loss 0.8293 Accuracy 0.7113
# Epoch 3 Batch 950 Loss 0.8295 Accuracy 0.7114
# Epoch 3 Batch 1000 Loss 0.8288 Accuracy 0.7115
# Epoch 3 Batch 1050 Loss 0.8272 Accuracy 0.7119
# Epoch 3 Batch 1100 Loss 0.8260 Accuracy 0.7122
# Epoch 3 Batch 1150 Loss 0.8255 Accuracy 0.7122
# Epoch 3 Batch 1200 Loss 0.8241 Accuracy 0.7122
# Epoch 3 Batch 1250 Loss 0.8228 Accuracy 0.7127
# Epoch 3 Batch 1300 Loss 0.8216 Accuracy 0.7131
# Epoch 3 Batch 1350 Loss 0.8207 Accuracy 0.7132
# Epoch 3 Batch 1400 Loss 0.8201 Accuracy 0.7134
# Epoch 3 Batch 1450 Loss 0.8200 Accuracy 0.7135
# Epoch 3 Batch 1500 Loss 0.8203 Accuracy 0.7131
# Epoch 3 Batch 1550 Loss 0.8199 Accuracy 0.7133
# Epoch 3 Batch 1600 Loss 0.8205 Accuracy 0.7133
# Epoch 3 Batch 1650 Loss 0.8205 Accuracy 0.7131
# Epoch 3 Batch 1700 Loss 0.8203 Accuracy 0.7130
# Epoch 3 Batch 1750 Loss 0.8207 Accuracy 0.7130
# Epoch 3 Batch 1800 Loss 0.8205 Accuracy 0.7130
# Epoch 3 Batch 1850 Loss 0.8206 Accuracy 0.7129
# Epoch 3 Batch 1900 Loss 0.8205 Accuracy 0.7130
# Epoch 3 Batch 1950 Loss 0.8207 Accuracy 0.7128
# Epoch 3 Batch 2000 Loss 0.8206 Accuracy 0.7130
# Epoch 3 Batch 2050 Loss 0.8203 Accuracy 0.7131
# Epoch 3 Batch 2100 Loss 0.8196 Accuracy 0.7134
# Epoch 3 Batch 2150 Loss 0.8190 Accuracy 0.7136
# Epoch 3 Batch 2200 Loss 0.8187 Accuracy 0.7138
# Epoch 3 Batch 2250 Loss 0.8184 Accuracy 0.7137
# Epoch 3 Batch 2300 Loss 0.8183 Accuracy 0.7136
# Epoch 3 Batch 2350 Loss 0.8183 Accuracy 0.7135
# Epoch 3 Batch 2400 Loss 0.8182 Accuracy 0.7134
# Epoch 3 Batch 2450 Loss 0.8178 Accuracy 0.7135
# Epoch 3 Batch 2500 Loss 0.8168 Accuracy 0.7137
# Epoch 3 Batch 2550 Loss 0.8165 Accuracy 0.7138
# Epoch 3 Batch 2600 Loss 0.8161 Accuracy 0.7141
# Epoch 3 Batch 2650 Loss 0.8163 Accuracy 0.7139
# Epoch 3 Batch 2700 Loss 0.8160 Accuracy 0.7140
# Epoch 3 Batch 2750 Loss 0.8154 Accuracy 0.7143
# Epoch 3 Batch 2800 Loss 0.8147 Accuracy 0.7144
# Epoch 3 Batch 2850 Loss 0.8147 Accuracy 0.7144
# Epoch 3 Batch 2900 Loss 0.8145 Accuracy 0.7144
# Epoch 3 Batch 2950 Loss 0.8141 Accuracy 0.7146
# Epoch 3 Batch 3000 Loss 0.8138 Accuracy 0.7146
# Epoch 3 Batch 3050 Loss 0.8134 Accuracy 0.7146
# Epoch 3 Batch 3100 Loss 0.8136 Accuracy 0.7146
# Epoch 3 Batch 3150 Loss 0.8132 Accuracy 0.7147
# Epoch 3 Batch 3200 Loss 0.8130 Accuracy 0.7148
# Epoch 3 Batch 3250 Loss 0.8125 Accuracy 0.7149
# Epoch 3 Batch 3300 Loss 0.8123 Accuracy 0.7150
# Epoch 3 Batch 3350 Loss 0.8121 Accuracy 0.7149
# Epoch 3 Batch 3400 Loss 0.8115 Accuracy 0.7149
# Epoch 3 Loss 0.8113 Accuracy 0.7151
# Time taken for 1 epoch: 74.69 secs
#
# Epoch 4 Batch 0 Loss 0.7535 Accuracy 0.7132
# Epoch 4 Batch 50 Loss 0.7933 Accuracy 0.7215
# Epoch 4 Batch 100 Loss 0.7800 Accuracy 0.7209
# Epoch 4 Batch 150 Loss 0.7716 Accuracy 0.7252
# Epoch 4 Batch 200 Loss 0.7639 Accuracy 0.7271
# Epoch 4 Batch 250 Loss 0.7640 Accuracy 0.7291
# Epoch 4 Batch 300 Loss 0.7626 Accuracy 0.7296
# Epoch 4 Batch 350 Loss 0.7601 Accuracy 0.7304
# Epoch 4 Batch 400 Loss 0.7580 Accuracy 0.7304
# Epoch 4 Batch 450 Loss 0.7568 Accuracy 0.7307
# Epoch 4 Batch 500 Loss 0.7556 Accuracy 0.7306
# Epoch 4 Batch 550 Loss 0.7548 Accuracy 0.7305
# Epoch 4 Batch 600 Loss 0.7535 Accuracy 0.7310
# Epoch 4 Batch 650 Loss 0.7528 Accuracy 0.7308
# Epoch 4 Batch 700 Loss 0.7521 Accuracy 0.7313
# Epoch 4 Batch 750 Loss 0.7520 Accuracy 0.7314
# Epoch 4 Batch 800 Loss 0.7509 Accuracy 0.7315
# Epoch 4 Batch 850 Loss 0.7504 Accuracy 0.7314
# Epoch 4 Batch 900 Loss 0.7507 Accuracy 0.7312
# Epoch 4 Batch 950 Loss 0.7515 Accuracy 0.7311
# Epoch 4 Batch 1000 Loss 0.7514 Accuracy 0.7308
# Epoch 4 Batch 1050 Loss 0.7521 Accuracy 0.7304
# Epoch 4 Batch 1100 Loss 0.7531 Accuracy 0.7303
# Epoch 4 Batch 1150 Loss 0.7525 Accuracy 0.7304
# Epoch 4 Batch 1200 Loss 0.7519 Accuracy 0.7307
# Epoch 4 Batch 1250 Loss 0.7507 Accuracy 0.7309
# Epoch 4 Batch 1300 Loss 0.7507 Accuracy 0.7312
# Epoch 4 Batch 1350 Loss 0.7506 Accuracy 0.7312
# Epoch 4 Batch 1400 Loss 0.7506 Accuracy 0.7313
# Epoch 4 Batch 1450 Loss 0.7501 Accuracy 0.7314
# Epoch 4 Batch 1500 Loss 0.7500 Accuracy 0.7314
# Epoch 4 Batch 1550 Loss 0.7504 Accuracy 0.7313
# Epoch 4 Batch 1600 Loss 0.7503 Accuracy 0.7311
# Epoch 4 Batch 1650 Loss 0.7503 Accuracy 0.7312
# Epoch 4 Batch 1700 Loss 0.7502 Accuracy 0.7313
# Epoch 4 Batch 1750 Loss 0.7504 Accuracy 0.7313
# Epoch 4 Batch 1800 Loss 0.7509 Accuracy 0.7313
# Epoch 4 Batch 1850 Loss 0.7510 Accuracy 0.7313
# Epoch 4 Batch 1900 Loss 0.7511 Accuracy 0.7312
# Epoch 4 Batch 1950 Loss 0.7511 Accuracy 0.7311
# Epoch 4 Batch 2000 Loss 0.7517 Accuracy 0.7309
# Epoch 4 Batch 2050 Loss 0.7526 Accuracy 0.7307
# Epoch 4 Batch 2100 Loss 0.7531 Accuracy 0.7305
# Epoch 4 Batch 2150 Loss 0.7533 Accuracy 0.7304
# Epoch 4 Batch 2200 Loss 0.7541 Accuracy 0.7300
# Epoch 4 Batch 2250 Loss 0.7542 Accuracy 0.7300
# Epoch 4 Batch 2300 Loss 0.7541 Accuracy 0.7300
# Epoch 4 Batch 2350 Loss 0.7540 Accuracy 0.7301
# Epoch 4 Batch 2400 Loss 0.7538 Accuracy 0.7302
# Epoch 4 Batch 2450 Loss 0.7536 Accuracy 0.7304
# Epoch 4 Batch 2500 Loss 0.7537 Accuracy 0.7305
# Epoch 4 Batch 2550 Loss 0.7539 Accuracy 0.7305
# Epoch 4 Batch 2600 Loss 0.7542 Accuracy 0.7303
# Epoch 4 Batch 2650 Loss 0.7541 Accuracy 0.7302
# Epoch 4 Batch 2700 Loss 0.7540 Accuracy 0.7303
# Epoch 4 Batch 2750 Loss 0.7540 Accuracy 0.7302
# Epoch 4 Batch 2800 Loss 0.7537 Accuracy 0.7303
# Epoch 4 Batch 2850 Loss 0.7541 Accuracy 0.7303
# Epoch 4 Batch 2900 Loss 0.7544 Accuracy 0.7301
# Epoch 4 Batch 2950 Loss 0.7544 Accuracy 0.7300
# Epoch 4 Batch 3000 Loss 0.7546 Accuracy 0.7299
# Epoch 4 Batch 3050 Loss 0.7547 Accuracy 0.7299
# Epoch 4 Batch 3100 Loss 0.7546 Accuracy 0.7299
# Epoch 4 Batch 3150 Loss 0.7546 Accuracy 0.7299
# Epoch 4 Batch 3200 Loss 0.7545 Accuracy 0.7298
# Epoch 4 Batch 3250 Loss 0.7541 Accuracy 0.7300
# Epoch 4 Batch 3300 Loss 0.7546 Accuracy 0.7298
# Epoch 4 Batch 3350 Loss 0.7545 Accuracy 0.7299
# Epoch 4 Batch 3400 Loss 0.7547 Accuracy 0.7298
# Epoch 4 Loss 0.7545 Accuracy 0.7298
# Time taken for 1 epoch: 74.59 secs
#
# Epoch 5 Batch 0 Loss 0.7707 Accuracy 0.7317
# Epoch 5 Batch 50 Loss 0.7490 Accuracy 0.7365
# Epoch 5 Batch 100 Loss 0.7293 Accuracy 0.7419
# Epoch 5 Batch 150 Loss 0.7287 Accuracy 0.7395
# Epoch 5 Batch 200 Loss 0.7325 Accuracy 0.7375
# Epoch 5 Batch 250 Loss 0.7273 Accuracy 0.7384
# Epoch 5 Batch 300 Loss 0.7239 Accuracy 0.7395
# Epoch 5 Batch 350 Loss 0.7204 Accuracy 0.7397
# Epoch 5 Batch 400 Loss 0.7185 Accuracy 0.7408
# Epoch 5 Batch 450 Loss 0.7184 Accuracy 0.7409
# Epoch 5 Batch 500 Loss 0.7170 Accuracy 0.7413
# Epoch 5 Batch 550 Loss 0.7165 Accuracy 0.7408
# Epoch 5 Batch 600 Loss 0.7165 Accuracy 0.7408
# Epoch 5 Batch 650 Loss 0.7164 Accuracy 0.7407
# Epoch 5 Batch 700 Loss 0.7151 Accuracy 0.7413
# Epoch 5 Batch 750 Loss 0.7164 Accuracy 0.7410
# Epoch 5 Batch 800 Loss 0.7147 Accuracy 0.7413
# Epoch 5 Batch 850 Loss 0.7143 Accuracy 0.7413
# Epoch 5 Batch 900 Loss 0.7136 Accuracy 0.7415
# Epoch 5 Batch 950 Loss 0.7131 Accuracy 0.7419
# Epoch 5 Batch 1000 Loss 0.7132 Accuracy 0.7418
# Epoch 5 Batch 1050 Loss 0.7150 Accuracy 0.7413
# Epoch 5 Batch 1100 Loss 0.7157 Accuracy 0.7411
# Epoch 5 Batch 1150 Loss 0.7149 Accuracy 0.7412
# Epoch 5 Batch 1200 Loss 0.7153 Accuracy 0.7409
# Epoch 5 Batch 1250 Loss 0.7147 Accuracy 0.7408
# Epoch 5 Batch 1300 Loss 0.7145 Accuracy 0.7405
# Epoch 5 Batch 1350 Loss 0.7148 Accuracy 0.7405
# Epoch 5 Batch 1400 Loss 0.7146 Accuracy 0.7408
# Epoch 5 Batch 1450 Loss 0.7147 Accuracy 0.7410
# Epoch 5 Batch 1500 Loss 0.7148 Accuracy 0.7408
# Epoch 5 Batch 1550 Loss 0.7153 Accuracy 0.7407
# Epoch 5 Batch 1600 Loss 0.7163 Accuracy 0.7402
# Epoch 5 Batch 1650 Loss 0.7170 Accuracy 0.7400
# Epoch 5 Batch 1700 Loss 0.7174 Accuracy 0.7400
# Epoch 5 Batch 1750 Loss 0.7184 Accuracy 0.7396
# Epoch 5 Batch 1800 Loss 0.7187 Accuracy 0.7395
# Epoch 5 Batch 1850 Loss 0.7185 Accuracy 0.7394
# Epoch 5 Batch 1900 Loss 0.7187 Accuracy 0.7394
# Epoch 5 Batch 1950 Loss 0.7194 Accuracy 0.7392
# Epoch 5 Batch 2000 Loss 0.7200 Accuracy 0.7389
# Epoch 5 Batch 2050 Loss 0.7201 Accuracy 0.7388
# Epoch 5 Batch 2100 Loss 0.7203 Accuracy 0.7386
# Epoch 5 Batch 2150 Loss 0.7209 Accuracy 0.7383
# Epoch 5 Batch 2200 Loss 0.7212 Accuracy 0.7382
# Epoch 5 Batch 2250 Loss 0.7214 Accuracy 0.7382
# Epoch 5 Batch 2300 Loss 0.7218 Accuracy 0.7381
# Epoch 5 Batch 2350 Loss 0.7218 Accuracy 0.7382
# Epoch 5 Batch 2400 Loss 0.7227 Accuracy 0.7378
# Epoch 5 Batch 2450 Loss 0.7234 Accuracy 0.7377
# Epoch 5 Batch 2500 Loss 0.7239 Accuracy 0.7376
# Epoch 5 Batch 2550 Loss 0.7241 Accuracy 0.7377
# Epoch 5 Batch 2600 Loss 0.7244 Accuracy 0.7374
# Epoch 5 Batch 2650 Loss 0.7248 Accuracy 0.7374
# Epoch 5 Batch 2700 Loss 0.7248 Accuracy 0.7375
# Epoch 5 Batch 2750 Loss 0.7249 Accuracy 0.7373
# Epoch 5 Batch 2800 Loss 0.7247 Accuracy 0.7372
# Epoch 5 Batch 2850 Loss 0.7253 Accuracy 0.7371
# Epoch 5 Batch 2900 Loss 0.7251 Accuracy 0.7371
# Epoch 5 Batch 2950 Loss 0.7249 Accuracy 0.7371
# Epoch 5 Batch 3000 Loss 0.7254 Accuracy 0.7369
# Epoch 5 Batch 3050 Loss 0.7249 Accuracy 0.7370
# Epoch 5 Batch 3100 Loss 0.7252 Accuracy 0.7369
# Epoch 5 Batch 3150 Loss 0.7252 Accuracy 0.7370
# Epoch 5 Batch 3200 Loss 0.7251 Accuracy 0.7369
# Epoch 5 Batch 3250 Loss 0.7246 Accuracy 0.7371
# Epoch 5 Batch 3300 Loss 0.7247 Accuracy 0.7370
# Epoch 5 Batch 3350 Loss 0.7246 Accuracy 0.7370
# Epoch 5 Batch 3400 Loss 0.7241 Accuracy 0.7373
# Saving checkpoint for epoch 5 at ./checkpoints/train4/ckpt-1
# Epoch 5 Loss 0.7240 Accuracy 0.7373
# Time taken for 1 epoch: 74.51 secs
#
# Epoch 6 Batch 0 Loss 0.6077 Accuracy 0.7710
# Epoch 6 Batch 50 Loss 0.6934 Accuracy 0.7506
# Epoch 6 Batch 100 Loss 0.6923 Accuracy 0.7468
# Epoch 6 Batch 150 Loss 0.6893 Accuracy 0.7473
# Epoch 6 Batch 200 Loss 0.6880 Accuracy 0.7473
# Epoch 6 Batch 250 Loss 0.6872 Accuracy 0.7472
# Epoch 6 Batch 300 Loss 0.6875 Accuracy 0.7477
# Epoch 6 Batch 350 Loss 0.6871 Accuracy 0.7475
# Epoch 6 Batch 400 Loss 0.6869 Accuracy 0.7481
# Epoch 6 Batch 450 Loss 0.6881 Accuracy 0.7479
# Epoch 6 Batch 500 Loss 0.6888 Accuracy 0.7479
# Epoch 6 Batch 550 Loss 0.6877 Accuracy 0.7479
# Epoch 6 Batch 600 Loss 0.6865 Accuracy 0.7479
# Epoch 6 Batch 650 Loss 0.6863 Accuracy 0.7480
# Epoch 6 Batch 700 Loss 0.6846 Accuracy 0.7484
# Epoch 6 Batch 750 Loss 0.6853 Accuracy 0.7487
# Epoch 6 Batch 800 Loss 0.6863 Accuracy 0.7483
# Epoch 6 Batch 850 Loss 0.6869 Accuracy 0.7480
# Epoch 6 Batch 900 Loss 0.6870 Accuracy 0.7479
# Epoch 6 Batch 950 Loss 0.6872 Accuracy 0.7479
# Epoch 6 Batch 1000 Loss 0.6866 Accuracy 0.7483
# Epoch 6 Batch 1050 Loss 0.6871 Accuracy 0.7478
# Epoch 6 Batch 1100 Loss 0.6875 Accuracy 0.7477
# Epoch 6 Batch 1150 Loss 0.6872 Accuracy 0.7480
# Epoch 6 Batch 1200 Loss 0.6881 Accuracy 0.7475
# Epoch 6 Batch 1250 Loss 0.6876 Accuracy 0.7477
# Epoch 6 Batch 1300 Loss 0.6875 Accuracy 0.7477
# Epoch 6 Batch 1350 Loss 0.6886 Accuracy 0.7473
# Epoch 6 Batch 1400 Loss 0.6883 Accuracy 0.7477
# Epoch 6 Batch 1450 Loss 0.6892 Accuracy 0.7473
# Epoch 6 Batch 1500 Loss 0.6899 Accuracy 0.7470
# Epoch 6 Batch 1550 Loss 0.6903 Accuracy 0.7467
# Epoch 6 Batch 1600 Loss 0.6908 Accuracy 0.7469
# Epoch 6 Batch 1650 Loss 0.6917 Accuracy 0.7468
# Epoch 6 Batch 1700 Loss 0.6924 Accuracy 0.7466
# Epoch 6 Batch 1750 Loss 0.6935 Accuracy 0.7462
# Epoch 6 Batch 1800 Loss 0.6946 Accuracy 0.7456
# Epoch 6 Batch 1850 Loss 0.6950 Accuracy 0.7454
# Epoch 6 Batch 1900 Loss 0.6958 Accuracy 0.7450
# Epoch 6 Batch 1950 Loss 0.6964 Accuracy 0.7449
# Epoch 6 Batch 2000 Loss 0.6969 Accuracy 0.7447
# Epoch 6 Batch 2050 Loss 0.6978 Accuracy 0.7444
# Epoch 6 Batch 2100 Loss 0.6983 Accuracy 0.7443
# Epoch 6 Batch 2150 Loss 0.6985 Accuracy 0.7441
# Epoch 6 Batch 2200 Loss 0.6983 Accuracy 0.7442
# Epoch 6 Batch 2250 Loss 0.6985 Accuracy 0.7442
# Epoch 6 Batch 2300 Loss 0.6990 Accuracy 0.7441
# Epoch 6 Batch 2350 Loss 0.6987 Accuracy 0.7442
# Epoch 6 Batch 2400 Loss 0.6987 Accuracy 0.7444
# Epoch 6 Batch 2450 Loss 0.6992 Accuracy 0.7442
# Epoch 6 Batch 2500 Loss 0.6997 Accuracy 0.7440
# Epoch 6 Batch 2550 Loss 0.7004 Accuracy 0.7437
# Epoch 6 Batch 2600 Loss 0.7006 Accuracy 0.7436
# Epoch 6 Batch 2650 Loss 0.7005 Accuracy 0.7436
# Epoch 6 Batch 2700 Loss 0.7009 Accuracy 0.7436
# Epoch 6 Batch 2750 Loss 0.7008 Accuracy 0.7435
# Epoch 6 Batch 2800 Loss 0.7013 Accuracy 0.7434
# Epoch 6 Batch 2850 Loss 0.7016 Accuracy 0.7433
# Epoch 6 Batch 2900 Loss 0.7017 Accuracy 0.7432
# Epoch 6 Batch 2950 Loss 0.7017 Accuracy 0.7432
# Epoch 6 Batch 3000 Loss 0.7019 Accuracy 0.7431
# Epoch 6 Batch 3050 Loss 0.7021 Accuracy 0.7431
# Epoch 6 Batch 3100 Loss 0.7024 Accuracy 0.7431
# Epoch 6 Batch 3150 Loss 0.7028 Accuracy 0.7429
# Epoch 6 Batch 3200 Loss 0.7030 Accuracy 0.7429
# Epoch 6 Batch 3250 Loss 0.7032 Accuracy 0.7429
# Epoch 6 Batch 3300 Loss 0.7032 Accuracy 0.7429
# Epoch 6 Batch 3350 Loss 0.7033 Accuracy 0.7428
# Epoch 6 Batch 3400 Loss 0.7035 Accuracy 0.7427
# Epoch 6 Loss 0.7038 Accuracy 0.7426
# Time taken for 1 epoch: 73.99 secs
#
# Epoch 7 Batch 0 Loss 0.7097 Accuracy 0.7500
# Epoch 7 Batch 50 Loss 0.6864 Accuracy 0.7432
# Epoch 7 Batch 100 Loss 0.6930 Accuracy 0.7427
# Epoch 7 Batch 150 Loss 0.6829 Accuracy 0.7459
# Epoch 7 Batch 200 Loss 0.6771 Accuracy 0.7485
# Epoch 7 Batch 250 Loss 0.6768 Accuracy 0.7483
# Epoch 7 Batch 300 Loss 0.6739 Accuracy 0.7509
# Epoch 7 Batch 350 Loss 0.6734 Accuracy 0.7511
# Epoch 7 Batch 400 Loss 0.6744 Accuracy 0.7511
# Epoch 7 Batch 450 Loss 0.6766 Accuracy 0.7509
# Epoch 7 Batch 500 Loss 0.6759 Accuracy 0.7512
# Epoch 7 Batch 550 Loss 0.6758 Accuracy 0.7519
# Epoch 7 Batch 600 Loss 0.6771 Accuracy 0.7515
# Epoch 7 Batch 650 Loss 0.6779 Accuracy 0.7508
# Epoch 7 Batch 700 Loss 0.6780 Accuracy 0.7510
# Epoch 7 Batch 750 Loss 0.6768 Accuracy 0.7513
# Epoch 7 Batch 800 Loss 0.6760 Accuracy 0.7512
# Epoch 7 Batch 850 Loss 0.6758 Accuracy 0.7508
# Epoch 7 Batch 900 Loss 0.6762 Accuracy 0.7506
# Epoch 7 Batch 950 Loss 0.6771 Accuracy 0.7499
# Epoch 7 Batch 1000 Loss 0.6769 Accuracy 0.7499
# Epoch 7 Batch 1050 Loss 0.6759 Accuracy 0.7502
# Epoch 7 Batch 1100 Loss 0.6761 Accuracy 0.7503
# Epoch 7 Batch 1150 Loss 0.6758 Accuracy 0.7507
# Epoch 7 Batch 1200 Loss 0.6773 Accuracy 0.7501
# Epoch 7 Batch 1250 Loss 0.6770 Accuracy 0.7501
# Epoch 7 Batch 1300 Loss 0.6770 Accuracy 0.7504
# Epoch 7 Batch 1350 Loss 0.6777 Accuracy 0.7502
# Epoch 7 Batch 1400 Loss 0.6777 Accuracy 0.7502
# Epoch 7 Batch 1450 Loss 0.6773 Accuracy 0.7503
# Epoch 7 Batch 1500 Loss 0.6775 Accuracy 0.7502
# Epoch 7 Batch 1550 Loss 0.6779 Accuracy 0.7501
# Epoch 7 Batch 1600 Loss 0.6783 Accuracy 0.7499
# Epoch 7 Batch 1650 Loss 0.6789 Accuracy 0.7496
# Epoch 7 Batch 1700 Loss 0.6788 Accuracy 0.7495
# Epoch 7 Batch 1750 Loss 0.6795 Accuracy 0.7493
# Epoch 7 Batch 1800 Loss 0.6795 Accuracy 0.7492
# Epoch 7 Batch 1850 Loss 0.6803 Accuracy 0.7491
# Epoch 7 Batch 1900 Loss 0.6810 Accuracy 0.7490
# Epoch 7 Batch 1950 Loss 0.6818 Accuracy 0.7487
# Epoch 7 Batch 2000 Loss 0.6821 Accuracy 0.7487
# Epoch 7 Batch 2050 Loss 0.6827 Accuracy 0.7486
# Epoch 7 Batch 2100 Loss 0.6829 Accuracy 0.7485
# Epoch 7 Batch 2150 Loss 0.6834 Accuracy 0.7484
# Epoch 7 Batch 2200 Loss 0.6837 Accuracy 0.7485
# Epoch 7 Batch 2250 Loss 0.6839 Accuracy 0.7485
# Epoch 7 Batch 2300 Loss 0.6845 Accuracy 0.7484
# Epoch 7 Batch 2350 Loss 0.6850 Accuracy 0.7480
# Epoch 7 Batch 2400 Loss 0.6855 Accuracy 0.7479
# Epoch 7 Batch 2450 Loss 0.6856 Accuracy 0.7478
# Epoch 7 Batch 2500 Loss 0.6855 Accuracy 0.7479
# Epoch 7 Batch 2550 Loss 0.6854 Accuracy 0.7479
# Epoch 7 Batch 2600 Loss 0.6857 Accuracy 0.7478
# Epoch 7 Batch 2650 Loss 0.6859 Accuracy 0.7477
# Epoch 7 Batch 2700 Loss 0.6862 Accuracy 0.7475
# Epoch 7 Batch 2750 Loss 0.6864 Accuracy 0.7476
# Epoch 7 Batch 2800 Loss 0.6865 Accuracy 0.7476
# Epoch 7 Batch 2850 Loss 0.6864 Accuracy 0.7477
# Epoch 7 Batch 2900 Loss 0.6865 Accuracy 0.7476
# Epoch 7 Batch 2950 Loss 0.6869 Accuracy 0.7475
# Epoch 7 Batch 3000 Loss 0.6870 Accuracy 0.7474
# Epoch 7 Batch 3050 Loss 0.6870 Accuracy 0.7473
# Epoch 7 Batch 3100 Loss 0.6866 Accuracy 0.7474
# Epoch 7 Batch 3150 Loss 0.6868 Accuracy 0.7473
# Epoch 7 Batch 3200 Loss 0.6871 Accuracy 0.7473
# Epoch 7 Batch 3250 Loss 0.6877 Accuracy 0.7471
# Epoch 7 Batch 3300 Loss 0.6882 Accuracy 0.7469
# Epoch 7 Batch 3350 Loss 0.6881 Accuracy 0.7470
# Epoch 7 Batch 3400 Loss 0.6884 Accuracy 0.7469
# Epoch 7 Loss 0.6886 Accuracy 0.7468
# Time taken for 1 epoch: 73.93 secs
#
# Epoch 8 Batch 0 Loss 0.6037 Accuracy 0.7680
# Epoch 8 Batch 50 Loss 0.6850 Accuracy 0.7452
# Epoch 8 Batch 100 Loss 0.6767 Accuracy 0.7495
# Epoch 8 Batch 150 Loss 0.6654 Accuracy 0.7538
# Epoch 8 Batch 200 Loss 0.6652 Accuracy 0.7538
# Epoch 8 Batch 250 Loss 0.6606 Accuracy 0.7543
# Epoch 8 Batch 300 Loss 0.6592 Accuracy 0.7545
# Epoch 8 Batch 350 Loss 0.6570 Accuracy 0.7557
# Epoch 8 Batch 400 Loss 0.6579 Accuracy 0.7565
# Epoch 8 Batch 450 Loss 0.6599 Accuracy 0.7556
# Epoch 8 Batch 500 Loss 0.6600 Accuracy 0.7558
# Epoch 8 Batch 550 Loss 0.6606 Accuracy 0.7558
# Epoch 8 Batch 600 Loss 0.6599 Accuracy 0.7554
# Epoch 8 Batch 650 Loss 0.6607 Accuracy 0.7552
# Epoch 8 Batch 700 Loss 0.6613 Accuracy 0.7552
# Epoch 8 Batch 750 Loss 0.6609 Accuracy 0.7555
# Epoch 8 Batch 800 Loss 0.6625 Accuracy 0.7548
# Epoch 8 Batch 850 Loss 0.6631 Accuracy 0.7545
# Epoch 8 Batch 900 Loss 0.6632 Accuracy 0.7543
# Epoch 8 Batch 950 Loss 0.6633 Accuracy 0.7541
# Epoch 8 Batch 1000 Loss 0.6630 Accuracy 0.7544
# Epoch 8 Batch 1050 Loss 0.6636 Accuracy 0.7542
# Epoch 8 Batch 1100 Loss 0.6635 Accuracy 0.7544
# Epoch 8 Batch 1150 Loss 0.6640 Accuracy 0.7539
# Epoch 8 Batch 1200 Loss 0.6643 Accuracy 0.7538
# Epoch 8 Batch 1250 Loss 0.6641 Accuracy 0.7541
# Epoch 8 Batch 1300 Loss 0.6637 Accuracy 0.7540
# Epoch 8 Batch 1350 Loss 0.6631 Accuracy 0.7542
# Epoch 8 Batch 1400 Loss 0.6628 Accuracy 0.7544
# Epoch 8 Batch 1450 Loss 0.6627 Accuracy 0.7543
# Epoch 8 Batch 1500 Loss 0.6633 Accuracy 0.7542
# Epoch 8 Batch 1550 Loss 0.6637 Accuracy 0.7542
# Epoch 8 Batch 1600 Loss 0.6644 Accuracy 0.7540
# Epoch 8 Batch 1650 Loss 0.6642 Accuracy 0.7542
# Epoch 8 Batch 1700 Loss 0.6644 Accuracy 0.7541
# Epoch 8 Batch 1750 Loss 0.6646 Accuracy 0.7540
# Epoch 8 Batch 1800 Loss 0.6654 Accuracy 0.7537
# Epoch 8 Batch 1850 Loss 0.6668 Accuracy 0.7533
# Epoch 8 Batch 1900 Loss 0.6673 Accuracy 0.7531
# Epoch 8 Batch 1950 Loss 0.6678 Accuracy 0.7529
# Epoch 8 Batch 2000 Loss 0.6686 Accuracy 0.7527
# Epoch 8 Batch 2050 Loss 0.6694 Accuracy 0.7526
# Epoch 8 Batch 2100 Loss 0.6701 Accuracy 0.7522
# Epoch 8 Batch 2150 Loss 0.6708 Accuracy 0.7521
# Epoch 8 Batch 2200 Loss 0.6710 Accuracy 0.7521
# Epoch 8 Batch 2250 Loss 0.6716 Accuracy 0.7520
# Epoch 8 Batch 2300 Loss 0.6726 Accuracy 0.7516
# Epoch 8 Batch 2350 Loss 0.6731 Accuracy 0.7514
# Epoch 8 Batch 2400 Loss 0.6734 Accuracy 0.7512
# Epoch 8 Batch 2450 Loss 0.6737 Accuracy 0.7510
# Epoch 8 Batch 2500 Loss 0.6741 Accuracy 0.7508
# Epoch 8 Batch 2550 Loss 0.6743 Accuracy 0.7508
# Epoch 8 Batch 2600 Loss 0.6746 Accuracy 0.7505
# Epoch 8 Batch 2650 Loss 0.6756 Accuracy 0.7500
# Epoch 8 Batch 2700 Loss 0.6756 Accuracy 0.7501
# Epoch 8 Batch 2750 Loss 0.6758 Accuracy 0.7500
# Epoch 8 Batch 2800 Loss 0.6758 Accuracy 0.7499
# Epoch 8 Batch 2850 Loss 0.6765 Accuracy 0.7498
# Epoch 8 Batch 2900 Loss 0.6769 Accuracy 0.7497
# Epoch 8 Batch 2950 Loss 0.6771 Accuracy 0.7497
# Epoch 8 Batch 3000 Loss 0.6771 Accuracy 0.7497
# Epoch 8 Batch 3050 Loss 0.6774 Accuracy 0.7496
# Epoch 8 Batch 3100 Loss 0.6777 Accuracy 0.7494
# Epoch 8 Batch 3150 Loss 0.6778 Accuracy 0.7494
# Epoch 8 Batch 3200 Loss 0.6778 Accuracy 0.7494
# Epoch 8 Batch 3250 Loss 0.6777 Accuracy 0.7496
# Epoch 8 Batch 3300 Loss 0.6780 Accuracy 0.7495
# Epoch 8 Batch 3350 Loss 0.6781 Accuracy 0.7495
# Epoch 8 Batch 3400 Loss 0.6782 Accuracy 0.7495
# Epoch 8 Loss 0.6781 Accuracy 0.7495
# Time taken for 1 epoch: 73.91 secs
#
# Epoch 9 Batch 0 Loss 0.5627 Accuracy 0.7943
# Epoch 9 Batch 50 Loss 0.6657 Accuracy 0.7600
# Epoch 9 Batch 100 Loss 0.6596 Accuracy 0.7587
# Epoch 9 Batch 150 Loss 0.6511 Accuracy 0.7587
# Epoch 9 Batch 200 Loss 0.6519 Accuracy 0.7587
# Epoch 9 Batch 250 Loss 0.6498 Accuracy 0.7583
# Epoch 9 Batch 300 Loss 0.6504 Accuracy 0.7584
# Epoch 9 Batch 350 Loss 0.6503 Accuracy 0.7585
# Epoch 9 Batch 400 Loss 0.6479 Accuracy 0.7600
# Epoch 9 Batch 450 Loss 0.6467 Accuracy 0.7604
# Epoch 9 Batch 500 Loss 0.6488 Accuracy 0.7595
# Epoch 9 Batch 550 Loss 0.6498 Accuracy 0.7594
# Epoch 9 Batch 600 Loss 0.6508 Accuracy 0.7588
# Epoch 9 Batch 650 Loss 0.6507 Accuracy 0.7589
# Epoch 9 Batch 700 Loss 0.6514 Accuracy 0.7586
# Epoch 9 Batch 750 Loss 0.6509 Accuracy 0.7584
# Epoch 9 Batch 800 Loss 0.6521 Accuracy 0.7579
# Epoch 9 Batch 850 Loss 0.6530 Accuracy 0.7573
# Epoch 9 Batch 900 Loss 0.6538 Accuracy 0.7571
# Epoch 9 Batch 950 Loss 0.6546 Accuracy 0.7567
# Epoch 9 Batch 1000 Loss 0.6550 Accuracy 0.7567
# Epoch 9 Batch 1050 Loss 0.6550 Accuracy 0.7567
# Epoch 9 Batch 1100 Loss 0.6549 Accuracy 0.7570
# Epoch 9 Batch 1150 Loss 0.6546 Accuracy 0.7570
# Epoch 9 Batch 1200 Loss 0.6558 Accuracy 0.7567
# Epoch 9 Batch 1250 Loss 0.6560 Accuracy 0.7566
# Epoch 9 Batch 1300 Loss 0.6553 Accuracy 0.7569
# Epoch 9 Batch 1350 Loss 0.6555 Accuracy 0.7569
# Epoch 9 Batch 1400 Loss 0.6563 Accuracy 0.7565
# Epoch 9 Batch 1450 Loss 0.6567 Accuracy 0.7566
# Epoch 9 Batch 1500 Loss 0.6576 Accuracy 0.7564
# Epoch 9 Batch 1550 Loss 0.6585 Accuracy 0.7561
# Epoch 9 Batch 1600 Loss 0.6587 Accuracy 0.7560
# Epoch 9 Batch 1650 Loss 0.6592 Accuracy 0.7563
# Epoch 9 Batch 1700 Loss 0.6596 Accuracy 0.7559
# Epoch 9 Batch 1750 Loss 0.6603 Accuracy 0.7558
# Epoch 9 Batch 1800 Loss 0.6607 Accuracy 0.7557
# Epoch 9 Batch 1850 Loss 0.6618 Accuracy 0.7554
# Epoch 9 Batch 1900 Loss 0.6626 Accuracy 0.7550
# Epoch 9 Batch 1950 Loss 0.6630 Accuracy 0.7548
# Epoch 9 Batch 2000 Loss 0.6634 Accuracy 0.7548
# Epoch 9 Batch 2050 Loss 0.6639 Accuracy 0.7546
# Epoch 9 Batch 2100 Loss 0.6641 Accuracy 0.7545
# Epoch 9 Batch 2150 Loss 0.6648 Accuracy 0.7543
# Epoch 9 Batch 2200 Loss 0.6657 Accuracy 0.7540
# Epoch 9 Batch 2250 Loss 0.6660 Accuracy 0.7539
# Epoch 9 Batch 2300 Loss 0.6661 Accuracy 0.7537
# Epoch 9 Batch 2350 Loss 0.6669 Accuracy 0.7535
# Epoch 9 Batch 2400 Loss 0.6670 Accuracy 0.7534
# Epoch 9 Batch 2450 Loss 0.6672 Accuracy 0.7534
# Epoch 9 Batch 2500 Loss 0.6679 Accuracy 0.7532
# Epoch 9 Batch 2550 Loss 0.6681 Accuracy 0.7529
# Epoch 9 Batch 2600 Loss 0.6677 Accuracy 0.7529
# Epoch 9 Batch 2650 Loss 0.6676 Accuracy 0.7530
# Epoch 9 Batch 2700 Loss 0.6677 Accuracy 0.7529
# Epoch 9 Batch 2750 Loss 0.6682 Accuracy 0.7527
# Epoch 9 Batch 2800 Loss 0.6687 Accuracy 0.7524
# Epoch 9 Batch 2850 Loss 0.6692 Accuracy 0.7522
# Epoch 9 Batch 2900 Loss 0.6692 Accuracy 0.7524
# Epoch 9 Batch 2950 Loss 0.6691 Accuracy 0.7524
# Epoch 9 Batch 3000 Loss 0.6691 Accuracy 0.7523
# Epoch 9 Batch 3050 Loss 0.6692 Accuracy 0.7522
# Epoch 9 Batch 3100 Loss 0.6695 Accuracy 0.7522
# Epoch 9 Batch 3150 Loss 0.6696 Accuracy 0.7521
# Epoch 9 Batch 3200 Loss 0.6698 Accuracy 0.7520
# Epoch 9 Batch 3250 Loss 0.6700 Accuracy 0.7520
# Epoch 9 Batch 3300 Loss 0.6703 Accuracy 0.7520
# Epoch 9 Batch 3350 Loss 0.6705 Accuracy 0.7518
# Epoch 9 Batch 3400 Loss 0.6705 Accuracy 0.7519
# Epoch 9 Loss 0.6708 Accuracy 0.7518
# Time taken for 1 epoch: 73.90 secs
#
# Epoch 10 Batch 0 Loss 0.6926 Accuracy 0.7172
# Epoch 10 Batch 50 Loss 0.6613 Accuracy 0.7570
# Epoch 10 Batch 100 Loss 0.6458 Accuracy 0.7595
# Epoch 10 Batch 150 Loss 0.6417 Accuracy 0.7620
# Epoch 10 Batch 200 Loss 0.6438 Accuracy 0.7610
# Epoch 10 Batch 250 Loss 0.6449 Accuracy 0.7604
# Epoch 10 Batch 300 Loss 0.6464 Accuracy 0.7604
# Epoch 10 Batch 350 Loss 0.6448 Accuracy 0.7603
# Epoch 10 Batch 400 Loss 0.6438 Accuracy 0.7602
# Epoch 10 Batch 450 Loss 0.6441 Accuracy 0.7604
# Epoch 10 Batch 500 Loss 0.6441 Accuracy 0.7607
# Epoch 10 Batch 550 Loss 0.6437 Accuracy 0.7608
# Epoch 10 Batch 600 Loss 0.6422 Accuracy 0.7611
# Epoch 10 Batch 650 Loss 0.6434 Accuracy 0.7609
# Epoch 10 Batch 700 Loss 0.6446 Accuracy 0.7606
# Epoch 10 Batch 750 Loss 0.6442 Accuracy 0.7601
# Epoch 10 Batch 800 Loss 0.6433 Accuracy 0.7603
# Epoch 10 Batch 850 Loss 0.6443 Accuracy 0.7597
# Epoch 10 Batch 900 Loss 0.6449 Accuracy 0.7594
# Epoch 10 Batch 950 Loss 0.6449 Accuracy 0.7592
# Epoch 10 Batch 1000 Loss 0.6446 Accuracy 0.7591
# Epoch 10 Batch 1050 Loss 0.6448 Accuracy 0.7593
# Epoch 10 Batch 1100 Loss 0.6462 Accuracy 0.7590
# Epoch 10 Batch 1150 Loss 0.6461 Accuracy 0.7589
# Epoch 10 Batch 1200 Loss 0.6478 Accuracy 0.7585
# Epoch 10 Batch 1250 Loss 0.6481 Accuracy 0.7584
# Epoch 10 Batch 1300 Loss 0.6477 Accuracy 0.7587
# Epoch 10 Batch 1350 Loss 0.6485 Accuracy 0.7584
# Epoch 10 Batch 1400 Loss 0.6494 Accuracy 0.7582
# Epoch 10 Batch 1450 Loss 0.6504 Accuracy 0.7580
# Epoch 10 Batch 1500 Loss 0.6508 Accuracy 0.7579
# Epoch 10 Batch 1550 Loss 0.6515 Accuracy 0.7576
# Epoch 10 Batch 1600 Loss 0.6518 Accuracy 0.7576
# Epoch 10 Batch 1650 Loss 0.6527 Accuracy 0.7572
# Epoch 10 Batch 1700 Loss 0.6536 Accuracy 0.7571
# Epoch 10 Batch 1750 Loss 0.6539 Accuracy 0.7569
# Epoch 10 Batch 1800 Loss 0.6549 Accuracy 0.7563
# Epoch 10 Batch 1850 Loss 0.6555 Accuracy 0.7560
# Epoch 10 Batch 1900 Loss 0.6559 Accuracy 0.7558
# Epoch 10 Batch 1950 Loss 0.6566 Accuracy 0.7555
# Epoch 10 Batch 2000 Loss 0.6565 Accuracy 0.7554
# Epoch 10 Batch 2050 Loss 0.6564 Accuracy 0.7554
# Epoch 10 Batch 2100 Loss 0.6567 Accuracy 0.7554
# Epoch 10 Batch 2150 Loss 0.6572 Accuracy 0.7554
# Epoch 10 Batch 2200 Loss 0.6576 Accuracy 0.7553
# Epoch 10 Batch 2250 Loss 0.6579 Accuracy 0.7551
# Epoch 10 Batch 2300 Loss 0.6581 Accuracy 0.7550
# Epoch 10 Batch 2350 Loss 0.6581 Accuracy 0.7551
# Epoch 10 Batch 2400 Loss 0.6589 Accuracy 0.7549
# Epoch 10 Batch 2450 Loss 0.6594 Accuracy 0.7547
# Epoch 10 Batch 2500 Loss 0.6598 Accuracy 0.7547
# Epoch 10 Batch 2550 Loss 0.6601 Accuracy 0.7546
# Epoch 10 Batch 2600 Loss 0.6604 Accuracy 0.7545
# Epoch 10 Batch 2650 Loss 0.6603 Accuracy 0.7544
# Epoch 10 Batch 2700 Loss 0.6606 Accuracy 0.7543
# Epoch 10 Batch 2750 Loss 0.6607 Accuracy 0.7543
# Epoch 10 Batch 2800 Loss 0.6608 Accuracy 0.7543
# Epoch 10 Batch 2850 Loss 0.6610 Accuracy 0.7542
# Epoch 10 Batch 2900 Loss 0.6613 Accuracy 0.7541
# Epoch 10 Batch 2950 Loss 0.6614 Accuracy 0.7540
# Epoch 10 Batch 3000 Loss 0.6614 Accuracy 0.7540
# Epoch 10 Batch 3050 Loss 0.6617 Accuracy 0.7539
# Epoch 10 Batch 3100 Loss 0.6621 Accuracy 0.7539
# Epoch 10 Batch 3150 Loss 0.6623 Accuracy 0.7538
# Epoch 10 Batch 3200 Loss 0.6623 Accuracy 0.7538
# Epoch 10 Batch 3250 Loss 0.6625 Accuracy 0.7537
# Epoch 10 Batch 3300 Loss 0.6629 Accuracy 0.7536
# Epoch 10 Batch 3350 Loss 0.6632 Accuracy 0.7536
# Epoch 10 Batch 3400 Loss 0.6634 Accuracy 0.7535
# Saving checkpoint for epoch 10 at ./checkpoints/train4/ckpt-2
# Epoch 10 Loss 0.6633 Accuracy 0.7536
# Time taken for 1 epoch: 73.82 secs
#
# Epoch 11 Batch 0 Loss 0.6930 Accuracy 0.7482
# Epoch 11 Batch 50 Loss 0.6492 Accuracy 0.7589
# Epoch 11 Batch 100 Loss 0.6314 Accuracy 0.7643
# Epoch 11 Batch 150 Loss 0.6295 Accuracy 0.7641
# Epoch 11 Batch 200 Loss 0.6277 Accuracy 0.7630
# Epoch 11 Batch 250 Loss 0.6298 Accuracy 0.7631
# Epoch 11 Batch 300 Loss 0.6317 Accuracy 0.7622
# Epoch 11 Batch 350 Loss 0.6332 Accuracy 0.7628
# Epoch 11 Batch 400 Loss 0.6339 Accuracy 0.7630
# Epoch 11 Batch 450 Loss 0.6334 Accuracy 0.7637
# Epoch 11 Batch 500 Loss 0.6312 Accuracy 0.7647
# Epoch 11 Batch 550 Loss 0.6333 Accuracy 0.7639
# Epoch 11 Batch 600 Loss 0.6333 Accuracy 0.7635
# Epoch 11 Batch 650 Loss 0.6351 Accuracy 0.7633
# Epoch 11 Batch 700 Loss 0.6360 Accuracy 0.7626
# Epoch 11 Batch 750 Loss 0.6358 Accuracy 0.7624
# Epoch 11 Batch 800 Loss 0.6372 Accuracy 0.7622
# Epoch 11 Batch 850 Loss 0.6375 Accuracy 0.7618
# Epoch 11 Batch 900 Loss 0.6376 Accuracy 0.7616
# Epoch 11 Batch 950 Loss 0.6372 Accuracy 0.7616
# Epoch 11 Batch 1000 Loss 0.6363 Accuracy 0.7619
# Epoch 11 Batch 1050 Loss 0.6364 Accuracy 0.7620
# Epoch 11 Batch 1100 Loss 0.6360 Accuracy 0.7621
# Epoch 11 Batch 1150 Loss 0.6364 Accuracy 0.7620
# Epoch 11 Batch 1200 Loss 0.6370 Accuracy 0.7619
# Epoch 11 Batch 1250 Loss 0.6371 Accuracy 0.7617
# Epoch 11 Batch 1300 Loss 0.6377 Accuracy 0.7618
# Epoch 11 Batch 1350 Loss 0.6381 Accuracy 0.7617
# Epoch 11 Batch 1400 Loss 0.6377 Accuracy 0.7619
# Epoch 11 Batch 1450 Loss 0.6380 Accuracy 0.7618
# Epoch 11 Batch 1500 Loss 0.6379 Accuracy 0.7617
# Epoch 11 Batch 1550 Loss 0.6387 Accuracy 0.7615
# Epoch 11 Batch 1600 Loss 0.6398 Accuracy 0.7612
# Epoch 11 Batch 1650 Loss 0.6402 Accuracy 0.7612
# Epoch 11 Batch 1700 Loss 0.6415 Accuracy 0.7607
# Epoch 11 Batch 1750 Loss 0.6417 Accuracy 0.7605
# Epoch 11 Batch 1800 Loss 0.6428 Accuracy 0.7600
# Epoch 11 Batch 1850 Loss 0.6433 Accuracy 0.7598
# Epoch 11 Batch 1900 Loss 0.6452 Accuracy 0.7593
# Epoch 11 Batch 1950 Loss 0.6463 Accuracy 0.7590
# Epoch 11 Batch 2000 Loss 0.6471 Accuracy 0.7587
# Epoch 11 Batch 2050 Loss 0.6480 Accuracy 0.7582
# Epoch 11 Batch 2100 Loss 0.6490 Accuracy 0.7577
# Epoch 11 Batch 2150 Loss 0.6501 Accuracy 0.7574
# Epoch 11 Batch 2200 Loss 0.6510 Accuracy 0.7569
# Epoch 11 Batch 2250 Loss 0.6513 Accuracy 0.7569
# Epoch 11 Batch 2300 Loss 0.6516 Accuracy 0.7568
# Epoch 11 Batch 2350 Loss 0.6523 Accuracy 0.7566
# Epoch 11 Batch 2400 Loss 0.6526 Accuracy 0.7564
# Epoch 11 Batch 2450 Loss 0.6530 Accuracy 0.7563
# Epoch 11 Batch 2500 Loss 0.6532 Accuracy 0.7563
# Epoch 11 Batch 2550 Loss 0.6537 Accuracy 0.7563
# Epoch 11 Batch 2600 Loss 0.6537 Accuracy 0.7561
# Epoch 11 Batch 2650 Loss 0.6539 Accuracy 0.7560
# Epoch 11 Batch 2700 Loss 0.6540 Accuracy 0.7560
# Epoch 11 Batch 2750 Loss 0.6545 Accuracy 0.7559
# Epoch 11 Batch 2800 Loss 0.6548 Accuracy 0.7558
# Epoch 11 Batch 2850 Loss 0.6553 Accuracy 0.7557
# Epoch 11 Batch 2900 Loss 0.6559 Accuracy 0.7555
# Epoch 11 Batch 2950 Loss 0.6560 Accuracy 0.7554
# Epoch 11 Batch 3000 Loss 0.6560 Accuracy 0.7554
# Epoch 11 Batch 3050 Loss 0.6562 Accuracy 0.7554
# Epoch 11 Batch 3100 Loss 0.6562 Accuracy 0.7554
# Epoch 11 Batch 3150 Loss 0.6564 Accuracy 0.7553
# Epoch 11 Batch 3200 Loss 0.6562 Accuracy 0.7554
# Epoch 11 Batch 3250 Loss 0.6565 Accuracy 0.7553
# Epoch 11 Batch 3300 Loss 0.6565 Accuracy 0.7553
# Epoch 11 Batch 3350 Loss 0.6569 Accuracy 0.7552
# Epoch 11 Batch 3400 Loss 0.6568 Accuracy 0.7552
# Epoch 11 Loss 0.6570 Accuracy 0.7552
# Time taken for 1 epoch: 73.98 secs
#
# Epoch 12 Batch 0 Loss 0.6277 Accuracy 0.7769
# Epoch 12 Batch 50 Loss 0.6278 Accuracy 0.7676
# Epoch 12 Batch 100 Loss 0.6346 Accuracy 0.7646
# Epoch 12 Batch 150 Loss 0.6361 Accuracy 0.7624
# Epoch 12 Batch 200 Loss 0.6349 Accuracy 0.7622
# Epoch 12 Batch 250 Loss 0.6336 Accuracy 0.7627
# Epoch 12 Batch 300 Loss 0.6320 Accuracy 0.7628
# Epoch 12 Batch 350 Loss 0.6336 Accuracy 0.7625
# Epoch 12 Batch 400 Loss 0.6330 Accuracy 0.7634
# Epoch 12 Batch 450 Loss 0.6312 Accuracy 0.7631
# Epoch 12 Batch 500 Loss 0.6323 Accuracy 0.7632
# Epoch 12 Batch 550 Loss 0.6316 Accuracy 0.7630
# Epoch 12 Batch 600 Loss 0.6326 Accuracy 0.7623
# Epoch 12 Batch 650 Loss 0.6329 Accuracy 0.7620
# Epoch 12 Batch 700 Loss 0.6336 Accuracy 0.7620
# Epoch 12 Batch 750 Loss 0.6347 Accuracy 0.7617
# Epoch 12 Batch 800 Loss 0.6333 Accuracy 0.7619
# Epoch 12 Batch 850 Loss 0.6323 Accuracy 0.7621
# Epoch 12 Batch 900 Loss 0.6322 Accuracy 0.7620
# Epoch 12 Batch 950 Loss 0.6335 Accuracy 0.7614
# Epoch 12 Batch 1000 Loss 0.6326 Accuracy 0.7617
# Epoch 12 Batch 1050 Loss 0.6333 Accuracy 0.7617
# Epoch 12 Batch 1100 Loss 0.6335 Accuracy 0.7612
# Epoch 12 Batch 1150 Loss 0.6336 Accuracy 0.7612
# Epoch 12 Batch 1200 Loss 0.6334 Accuracy 0.7613
# Epoch 12 Batch 1250 Loss 0.6334 Accuracy 0.7615
# Epoch 12 Batch 1300 Loss 0.6340 Accuracy 0.7613
# Epoch 12 Batch 1350 Loss 0.6344 Accuracy 0.7615
# Epoch 12 Batch 1400 Loss 0.6345 Accuracy 0.7615
# Epoch 12 Batch 1450 Loss 0.6350 Accuracy 0.7615
# Epoch 12 Batch 1500 Loss 0.6351 Accuracy 0.7615
# Epoch 12 Batch 1550 Loss 0.6358 Accuracy 0.7614
# Epoch 12 Batch 1600 Loss 0.6357 Accuracy 0.7618
# Epoch 12 Batch 1650 Loss 0.6360 Accuracy 0.7615
# Epoch 12 Batch 1700 Loss 0.6368 Accuracy 0.7613
# Epoch 12 Batch 1750 Loss 0.6377 Accuracy 0.7610
# Epoch 12 Batch 1800 Loss 0.6389 Accuracy 0.7608
# Epoch 12 Batch 1850 Loss 0.6398 Accuracy 0.7606
# Epoch 12 Batch 1900 Loss 0.6404 Accuracy 0.7603
# Epoch 12 Batch 1950 Loss 0.6415 Accuracy 0.7598
# Epoch 12 Batch 2000 Loss 0.6425 Accuracy 0.7596
# Epoch 12 Batch 2050 Loss 0.6434 Accuracy 0.7593
# Epoch 12 Batch 2100 Loss 0.6440 Accuracy 0.7591
# Epoch 12 Batch 2150 Loss 0.6442 Accuracy 0.7588
# Epoch 12 Batch 2200 Loss 0.6451 Accuracy 0.7586
# Epoch 12 Batch 2250 Loss 0.6451 Accuracy 0.7586
# Epoch 12 Batch 2300 Loss 0.6457 Accuracy 0.7584
# Epoch 12 Batch 2350 Loss 0.6463 Accuracy 0.7583
# Epoch 12 Batch 2400 Loss 0.6467 Accuracy 0.7583
# Epoch 12 Batch 2450 Loss 0.6472 Accuracy 0.7580
# Epoch 12 Batch 2500 Loss 0.6476 Accuracy 0.7580
# Epoch 12 Batch 2550 Loss 0.6483 Accuracy 0.7578
# Epoch 12 Batch 2600 Loss 0.6488 Accuracy 0.7576
# Epoch 12 Batch 2650 Loss 0.6488 Accuracy 0.7577
# Epoch 12 Batch 2700 Loss 0.6493 Accuracy 0.7577
# Epoch 12 Batch 2750 Loss 0.6495 Accuracy 0.7576
# Epoch 12 Batch 2800 Loss 0.6496 Accuracy 0.7575
# Epoch 12 Batch 2850 Loss 0.6497 Accuracy 0.7576
# Epoch 12 Batch 2900 Loss 0.6501 Accuracy 0.7575
# Epoch 12 Batch 2950 Loss 0.6504 Accuracy 0.7574
# Epoch 12 Batch 3000 Loss 0.6503 Accuracy 0.7574
# Epoch 12 Batch 3050 Loss 0.6509 Accuracy 0.7572
# Epoch 12 Batch 3100 Loss 0.6509 Accuracy 0.7572
# Epoch 12 Batch 3150 Loss 0.6512 Accuracy 0.7571
# Epoch 12 Batch 3200 Loss 0.6514 Accuracy 0.7570
# Epoch 12 Batch 3250 Loss 0.6518 Accuracy 0.7569
# Epoch 12 Batch 3300 Loss 0.6519 Accuracy 0.7568
# Epoch 12 Batch 3350 Loss 0.6524 Accuracy 0.7566
# Epoch 12 Batch 3400 Loss 0.6524 Accuracy 0.7566
# Epoch 12 Loss 0.6526 Accuracy 0.7565
# Time taken for 1 epoch: 74.43 secs
#
# Epoch 13 Batch 0 Loss 0.7058 Accuracy 0.7218
# Epoch 13 Batch 50 Loss 0.6366 Accuracy 0.7547
# Epoch 13 Batch 100 Loss 0.6319 Accuracy 0.7595
# Epoch 13 Batch 150 Loss 0.6324 Accuracy 0.7602
# Epoch 13 Batch 200 Loss 0.6262 Accuracy 0.7622
# Epoch 13 Batch 250 Loss 0.6262 Accuracy 0.7631
# Epoch 13 Batch 300 Loss 0.6273 Accuracy 0.7628
# Epoch 13 Batch 350 Loss 0.6265 Accuracy 0.7639
# Epoch 13 Batch 400 Loss 0.6242 Accuracy 0.7652
# Epoch 13 Batch 450 Loss 0.6228 Accuracy 0.7655
# Epoch 13 Batch 500 Loss 0.6245 Accuracy 0.7649
# Epoch 13 Batch 550 Loss 0.6276 Accuracy 0.7639
# Epoch 13 Batch 600 Loss 0.6268 Accuracy 0.7638
# Epoch 13 Batch 650 Loss 0.6256 Accuracy 0.7641
# Epoch 13 Batch 700 Loss 0.6266 Accuracy 0.7637
# Epoch 13 Batch 750 Loss 0.6269 Accuracy 0.7635
# Epoch 13 Batch 800 Loss 0.6265 Accuracy 0.7636
# Epoch 13 Batch 850 Loss 0.6269 Accuracy 0.7634
# Epoch 13 Batch 900 Loss 0.6268 Accuracy 0.7633
# Epoch 13 Batch 950 Loss 0.6271 Accuracy 0.7633
# Epoch 13 Batch 1000 Loss 0.6276 Accuracy 0.7633
# Epoch 13 Batch 1050 Loss 0.6282 Accuracy 0.7632
# Epoch 13 Batch 1100 Loss 0.6277 Accuracy 0.7636
# Epoch 13 Batch 1150 Loss 0.6281 Accuracy 0.7638
# Epoch 13 Batch 1200 Loss 0.6287 Accuracy 0.7635
# Epoch 13 Batch 1250 Loss 0.6287 Accuracy 0.7635
# Epoch 13 Batch 1300 Loss 0.6294 Accuracy 0.7633
# Epoch 13 Batch 1350 Loss 0.6288 Accuracy 0.7633
# Epoch 13 Batch 1400 Loss 0.6287 Accuracy 0.7634
# Epoch 13 Batch 1450 Loss 0.6286 Accuracy 0.7636
# Epoch 13 Batch 1500 Loss 0.6292 Accuracy 0.7634
# Epoch 13 Batch 1550 Loss 0.6290 Accuracy 0.7636
# Epoch 13 Batch 1600 Loss 0.6303 Accuracy 0.7631
# Epoch 13 Batch 1650 Loss 0.6303 Accuracy 0.7632
# Epoch 13 Batch 1700 Loss 0.6305 Accuracy 0.7631
# Epoch 13 Batch 1750 Loss 0.6312 Accuracy 0.7630
# Epoch 13 Batch 1800 Loss 0.6313 Accuracy 0.7629
# Epoch 13 Batch 1850 Loss 0.6323 Accuracy 0.7626
# Epoch 13 Batch 1900 Loss 0.6331 Accuracy 0.7623
# Epoch 13 Batch 1950 Loss 0.6341 Accuracy 0.7621
# Epoch 13 Batch 2000 Loss 0.6351 Accuracy 0.7617
# Epoch 13 Batch 2050 Loss 0.6356 Accuracy 0.7616
# Epoch 13 Batch 2100 Loss 0.6364 Accuracy 0.7613
# Epoch 13 Batch 2150 Loss 0.6369 Accuracy 0.7610
# Epoch 13 Batch 2200 Loss 0.6379 Accuracy 0.7607
# Epoch 13 Batch 2250 Loss 0.6390 Accuracy 0.7604
# Epoch 13 Batch 2300 Loss 0.6392 Accuracy 0.7603
# Epoch 13 Batch 2350 Loss 0.6397 Accuracy 0.7601
# Epoch 13 Batch 2400 Loss 0.6402 Accuracy 0.7599
# Epoch 13 Batch 2450 Loss 0.6404 Accuracy 0.7598
# Epoch 13 Batch 2500 Loss 0.6411 Accuracy 0.7595
# Epoch 13 Batch 2550 Loss 0.6417 Accuracy 0.7593
# Epoch 13 Batch 2600 Loss 0.6426 Accuracy 0.7590
# Epoch 13 Batch 2650 Loss 0.6434 Accuracy 0.7588
# Epoch 13 Batch 2700 Loss 0.6437 Accuracy 0.7587
# Epoch 13 Batch 2750 Loss 0.6443 Accuracy 0.7588
# Epoch 13 Batch 2800 Loss 0.6446 Accuracy 0.7586
# Epoch 13 Batch 2850 Loss 0.6451 Accuracy 0.7585
# Epoch 13 Batch 2900 Loss 0.6455 Accuracy 0.7583
# Epoch 13 Batch 2950 Loss 0.6454 Accuracy 0.7584
# Epoch 13 Batch 3000 Loss 0.6461 Accuracy 0.7582
# Epoch 13 Batch 3050 Loss 0.6463 Accuracy 0.7582
# Epoch 13 Batch 3100 Loss 0.6465 Accuracy 0.7580
# Epoch 13 Batch 3150 Loss 0.6467 Accuracy 0.7579
# Epoch 13 Batch 3200 Loss 0.6467 Accuracy 0.7579
# Epoch 13 Batch 3250 Loss 0.6470 Accuracy 0.7578
# Epoch 13 Batch 3300 Loss 0.6471 Accuracy 0.7577
# Epoch 13 Batch 3350 Loss 0.6475 Accuracy 0.7577
# Epoch 13 Batch 3400 Loss 0.6478 Accuracy 0.7576
# Epoch 13 Loss 0.6479 Accuracy 0.7575
# Time taken for 1 epoch: 74.18 secs
#
# Epoch 14 Batch 0 Loss 0.5619 Accuracy 0.7464
# Epoch 14 Batch 50 Loss 0.6514 Accuracy 0.7571
# Epoch 14 Batch 100 Loss 0.6389 Accuracy 0.7609
# Epoch 14 Batch 150 Loss 0.6322 Accuracy 0.7627
# Epoch 14 Batch 200 Loss 0.6290 Accuracy 0.7645
# Epoch 14 Batch 250 Loss 0.6292 Accuracy 0.7642
# Epoch 14 Batch 300 Loss 0.6262 Accuracy 0.7646
# Epoch 14 Batch 350 Loss 0.6239 Accuracy 0.7665
# Epoch 14 Batch 400 Loss 0.6259 Accuracy 0.7656
# Epoch 14 Batch 450 Loss 0.6235 Accuracy 0.7662
# Epoch 14 Batch 500 Loss 0.6233 Accuracy 0.7663
# Epoch 14 Batch 550 Loss 0.6225 Accuracy 0.7665
# Epoch 14 Batch 600 Loss 0.6247 Accuracy 0.7656
# Epoch 14 Batch 650 Loss 0.6257 Accuracy 0.7653
# Epoch 14 Batch 700 Loss 0.6253 Accuracy 0.7659
# Epoch 14 Batch 750 Loss 0.6275 Accuracy 0.7652
# Epoch 14 Batch 800 Loss 0.6286 Accuracy 0.7646
# Epoch 14 Batch 850 Loss 0.6302 Accuracy 0.7640
# Epoch 14 Batch 900 Loss 0.6311 Accuracy 0.7632
# Epoch 14 Batch 950 Loss 0.6309 Accuracy 0.7632
# Epoch 14 Batch 1000 Loss 0.6313 Accuracy 0.7629
# Epoch 14 Batch 1050 Loss 0.6313 Accuracy 0.7628
# Epoch 14 Batch 1100 Loss 0.6319 Accuracy 0.7628
# Epoch 14 Batch 1150 Loss 0.6316 Accuracy 0.7630
# Epoch 14 Batch 1200 Loss 0.6309 Accuracy 0.7631
# Epoch 14 Batch 1250 Loss 0.6315 Accuracy 0.7630
# Epoch 14 Batch 1300 Loss 0.6322 Accuracy 0.7628
# Epoch 14 Batch 1350 Loss 0.6324 Accuracy 0.7627
# Epoch 14 Batch 1400 Loss 0.6321 Accuracy 0.7626
# Epoch 14 Batch 1450 Loss 0.6318 Accuracy 0.7628
# Epoch 14 Batch 1500 Loss 0.6315 Accuracy 0.7629
# Epoch 14 Batch 1550 Loss 0.6319 Accuracy 0.7629
# Epoch 14 Batch 1600 Loss 0.6332 Accuracy 0.7625
# Epoch 14 Batch 1650 Loss 0.6337 Accuracy 0.7625
# Epoch 14 Batch 1700 Loss 0.6335 Accuracy 0.7624
# Epoch 14 Batch 1750 Loss 0.6335 Accuracy 0.7623
# Epoch 14 Batch 1800 Loss 0.6342 Accuracy 0.7619
# Epoch 14 Batch 1850 Loss 0.6350 Accuracy 0.7618
# Epoch 14 Batch 1900 Loss 0.6354 Accuracy 0.7616
# Epoch 14 Batch 1950 Loss 0.6356 Accuracy 0.7615
# Epoch 14 Batch 2000 Loss 0.6359 Accuracy 0.7614
# Epoch 14 Batch 2050 Loss 0.6363 Accuracy 0.7614
# Epoch 14 Batch 2100 Loss 0.6370 Accuracy 0.7611
# Epoch 14 Batch 2150 Loss 0.6371 Accuracy 0.7611
# Epoch 14 Batch 2200 Loss 0.6380 Accuracy 0.7609
# Epoch 14 Batch 2250 Loss 0.6387 Accuracy 0.7606
# Epoch 14 Batch 2300 Loss 0.6391 Accuracy 0.7605
# Epoch 14 Batch 2350 Loss 0.6395 Accuracy 0.7604
# Epoch 14 Batch 2400 Loss 0.6399 Accuracy 0.7604
# Epoch 14 Batch 2450 Loss 0.6399 Accuracy 0.7603
# Epoch 14 Batch 2500 Loss 0.6402 Accuracy 0.7602
# Epoch 14 Batch 2550 Loss 0.6412 Accuracy 0.7598
# Epoch 14 Batch 2600 Loss 0.6419 Accuracy 0.7594
# Epoch 14 Batch 2650 Loss 0.6420 Accuracy 0.7594
# Epoch 14 Batch 2700 Loss 0.6424 Accuracy 0.7592
# Epoch 14 Batch 2750 Loss 0.6425 Accuracy 0.7592
# Epoch 14 Batch 2800 Loss 0.6427 Accuracy 0.7591
# Epoch 14 Batch 2850 Loss 0.6430 Accuracy 0.7590
# Epoch 14 Batch 2900 Loss 0.6433 Accuracy 0.7590
# Epoch 14 Batch 2950 Loss 0.6431 Accuracy 0.7591
# Epoch 14 Batch 3000 Loss 0.6435 Accuracy 0.7589
# Epoch 14 Batch 3050 Loss 0.6438 Accuracy 0.7588
# Epoch 14 Batch 3100 Loss 0.6440 Accuracy 0.7587
# Epoch 14 Batch 3150 Loss 0.6444 Accuracy 0.7586
# Epoch 14 Batch 3200 Loss 0.6446 Accuracy 0.7586
# Epoch 14 Batch 3250 Loss 0.6449 Accuracy 0.7584
# Epoch 14 Batch 3300 Loss 0.6453 Accuracy 0.7583
# Epoch 14 Batch 3350 Loss 0.6453 Accuracy 0.7583
# Epoch 14 Batch 3400 Loss 0.6454 Accuracy 0.7582
# Epoch 14 Loss 0.6456 Accuracy 0.7581
# Time taken for 1 epoch: 73.61 secs
#
# Epoch 15 Batch 0 Loss 0.5951 Accuracy 0.7292
# Epoch 15 Batch 50 Loss 0.6101 Accuracy 0.7615
# Epoch 15 Batch 100 Loss 0.6115 Accuracy 0.7665
# Epoch 15 Batch 150 Loss 0.6203 Accuracy 0.7634
# Epoch 15 Batch 200 Loss 0.6180 Accuracy 0.7642
# Epoch 15 Batch 250 Loss 0.6187 Accuracy 0.7655
# Epoch 15 Batch 300 Loss 0.6195 Accuracy 0.7652
# Epoch 15 Batch 350 Loss 0.6214 Accuracy 0.7648
# Epoch 15 Batch 400 Loss 0.6221 Accuracy 0.7651
# Epoch 15 Batch 450 Loss 0.6243 Accuracy 0.7648
# Epoch 15 Batch 500 Loss 0.6236 Accuracy 0.7648
# Epoch 15 Batch 550 Loss 0.6227 Accuracy 0.7651
# Epoch 15 Batch 600 Loss 0.6221 Accuracy 0.7654
# Epoch 15 Batch 650 Loss 0.6239 Accuracy 0.7646
# Epoch 15 Batch 700 Loss 0.6241 Accuracy 0.7646
# Epoch 15 Batch 750 Loss 0.6238 Accuracy 0.7646
# Epoch 15 Batch 800 Loss 0.6247 Accuracy 0.7640
# Epoch 15 Batch 850 Loss 0.6253 Accuracy 0.7636
# Epoch 15 Batch 900 Loss 0.6244 Accuracy 0.7640
# Epoch 15 Batch 950 Loss 0.6248 Accuracy 0.7641
# Epoch 15 Batch 1000 Loss 0.6251 Accuracy 0.7641
# Epoch 15 Batch 1050 Loss 0.6259 Accuracy 0.7642
# Epoch 15 Batch 1100 Loss 0.6251 Accuracy 0.7644
# Epoch 15 Batch 1150 Loss 0.6257 Accuracy 0.7644
# Epoch 15 Batch 1200 Loss 0.6256 Accuracy 0.7643
# Epoch 15 Batch 1250 Loss 0.6261 Accuracy 0.7640
# Epoch 15 Batch 1300 Loss 0.6257 Accuracy 0.7642
# Epoch 15 Batch 1350 Loss 0.6251 Accuracy 0.7641
# Epoch 15 Batch 1400 Loss 0.6262 Accuracy 0.7641
# Epoch 15 Batch 1450 Loss 0.6269 Accuracy 0.7639
# ...
# Epoch 26 Batch 950 Loss 0.5930 Accuracy 0.7732
# Epoch 26 Batch 1000 Loss 0.5935 Accuracy 0.7729
# Epoch 26 Batch 1050 Loss 0.5938 Accuracy 0.7727
# Epoch 26 Batch 1100 Loss 0.5936 Accuracy 0.7727
# Epoch 26 Batch 1150 Loss 0.5938 Accuracy 0.7727
# Epoch 26 Batch 1200 Loss 0.5954 Accuracy 0.7721
# Epoch 26 Batch 1250 Loss 0.5950 Accuracy 0.7723
# Epoch 26 Batch 1300 Loss 0.5951 Accuracy 0.7722
# Epoch 26 Batch 1350 Loss 0.5950 Accuracy 0.7721
# Epoch 26 Batch 1400 Loss 0.5954 Accuracy 0.7724
# Epoch 26 Batch 1450 Loss 0.5966 Accuracy 0.7722
# Epoch 26 Batch 1500 Loss 0.5967 Accuracy 0.7723
# Epoch 26 Batch 1550 Loss 0.5966 Accuracy 0.7724
# Epoch 26 Batch 1600 Loss 0.5973 Accuracy 0.7722
# Epoch 26 Batch 1650 Loss 0.5981 Accuracy 0.7719
# Epoch 26 Batch 1700 Loss 0.5986 Accuracy 0.7716
# Epoch 26 Batch 1750 Loss 0.5999 Accuracy 0.7712
# Epoch 26 Batch 1800 Loss 0.6008 Accuracy 0.7709
# Epoch 26 Batch 1850 Loss 0.6017 Accuracy 0.7706
# Epoch 26 Batch 1900 Loss 0.6024 Accuracy 0.7704
# Epoch 26 Batch 1950 Loss 0.6031 Accuracy 0.7701
# Epoch 26 Batch 2000 Loss 0.6034 Accuracy 0.7698
# Epoch 26 Batch 2050 Loss 0.6038 Accuracy 0.7697
# Epoch 26 Batch 2100 Loss 0.6049 Accuracy 0.7693
# Epoch 26 Batch 2150 Loss 0.6055 Accuracy 0.7691
# Epoch 26 Batch 2200 Loss 0.6059 Accuracy 0.7691
# Epoch 26 Batch 2250 Loss 0.6067 Accuracy 0.7688
# Epoch 26 Batch 2300 Loss 0.6078 Accuracy 0.7684
# Epoch 26 Batch 2350 Loss 0.6080 Accuracy 0.7683
# Epoch 26 Batch 2400 Loss 0.6083 Accuracy 0.7684
# Epoch 26 Batch 2450 Loss 0.6086 Accuracy 0.7684
# Epoch 26 Batch 2500 Loss 0.6091 Accuracy 0.7682
# Epoch 26 Batch 2550 Loss 0.6094 Accuracy 0.7681
# Epoch 26 Batch 2600 Loss 0.6098 Accuracy 0.7680
# Epoch 26 Batch 2650 Loss 0.6101 Accuracy 0.7679
# Epoch 26 Batch 2700 Loss 0.6104 Accuracy 0.7678
# Epoch 26 Batch 2750 Loss 0.6105 Accuracy 0.7677
# Epoch 26 Batch 2800 Loss 0.6110 Accuracy 0.7674
# Epoch 26 Batch 2850 Loss 0.6115 Accuracy 0.7673
# Epoch 26 Batch 2900 Loss 0.6118 Accuracy 0.7672
# Epoch 26 Batch 2950 Loss 0.6120 Accuracy 0.7670
# Epoch 26 Batch 3000 Loss 0.6127 Accuracy 0.7668
# Epoch 26 Batch 3050 Loss 0.6134 Accuracy 0.7665
# Epoch 26 Batch 3100 Loss 0.6136 Accuracy 0.7665
# Epoch 26 Batch 3150 Loss 0.6142 Accuracy 0.7663
# Epoch 26 Batch 3200 Loss 0.6148 Accuracy 0.7661
# Epoch 26 Batch 3250 Loss 0.6151 Accuracy 0.7660
# Epoch 26 Batch 3300 Loss 0.6154 Accuracy 0.7658
# Epoch 26 Batch 3350 Loss 0.6159 Accuracy 0.7657
# Epoch 26 Batch 3400 Loss 0.6162 Accuracy 0.7656
# Epoch 26 Loss 0.6164 Accuracy 0.7655
# Time taken for 1 epoch: 73.69 secs
#
# Epoch 27 Batch 0 Loss 0.6662 Accuracy 0.7426
# Epoch 27 Batch 50 Loss 0.6092 Accuracy 0.7688
# Epoch 27 Batch 100 Loss 0.5986 Accuracy 0.7717
# Epoch 27 Batch 150 Loss 0.5918 Accuracy 0.7741
# Epoch 27 Batch 200 Loss 0.5944 Accuracy 0.7726
# Epoch 27 Batch 250 Loss 0.5930 Accuracy 0.7730
# Epoch 27 Batch 300 Loss 0.5909 Accuracy 0.7742
# Epoch 27 Batch 350 Loss 0.5938 Accuracy 0.7727
# Epoch 27 Batch 400 Loss 0.5935 Accuracy 0.7728
# Epoch 27 Batch 450 Loss 0.5952 Accuracy 0.7725
# Epoch 27 Batch 500 Loss 0.5946 Accuracy 0.7726
# Epoch 27 Batch 550 Loss 0.5930 Accuracy 0.7729
# Epoch 27 Batch 600 Loss 0.5932 Accuracy 0.7727
# Epoch 27 Batch 650 Loss 0.5943 Accuracy 0.7725
# Epoch 27 Batch 700 Loss 0.5940 Accuracy 0.7726
# Epoch 27 Batch 750 Loss 0.5932 Accuracy 0.7730
# Epoch 27 Batch 800 Loss 0.5926 Accuracy 0.7733
# Epoch 27 Batch 850 Loss 0.5942 Accuracy 0.7728
# Epoch 27 Batch 900 Loss 0.5951 Accuracy 0.7725
# Epoch 27 Batch 950 Loss 0.5957 Accuracy 0.7723
# Epoch 27 Batch 1000 Loss 0.5974 Accuracy 0.7716
# Epoch 27 Batch 1050 Loss 0.5969 Accuracy 0.7714
# Epoch 27 Batch 1100 Loss 0.5978 Accuracy 0.7711
# Epoch 27 Batch 1150 Loss 0.5983 Accuracy 0.7710
# Epoch 27 Batch 1200 Loss 0.5977 Accuracy 0.7712
# Epoch 27 Batch 1250 Loss 0.5977 Accuracy 0.7713
# Epoch 27 Batch 1300 Loss 0.5982 Accuracy 0.7709
# Epoch 27 Batch 1350 Loss 0.5984 Accuracy 0.7710
# Epoch 27 Batch 1400 Loss 0.5977 Accuracy 0.7715
# Epoch 27 Batch 1450 Loss 0.5988 Accuracy 0.7713
# Epoch 27 Batch 1500 Loss 0.5983 Accuracy 0.7715
# Epoch 27 Batch 1550 Loss 0.5991 Accuracy 0.7713
# Epoch 27 Batch 1600 Loss 0.5996 Accuracy 0.7712
# Epoch 27 Batch 1650 Loss 0.5999 Accuracy 0.7712
# Epoch 27 Batch 1700 Loss 0.6000 Accuracy 0.7711
# Epoch 27 Batch 1750 Loss 0.6012 Accuracy 0.7707
# Epoch 27 Batch 1800 Loss 0.6023 Accuracy 0.7704
# Epoch 27 Batch 1850 Loss 0.6032 Accuracy 0.7701
# Epoch 27 Batch 1900 Loss 0.6040 Accuracy 0.7698
# Epoch 27 Batch 1950 Loss 0.6042 Accuracy 0.7696
# Epoch 27 Batch 2000 Loss 0.6048 Accuracy 0.7695
# Epoch 27 Batch 2050 Loss 0.6054 Accuracy 0.7694
# Epoch 27 Batch 2100 Loss 0.6064 Accuracy 0.7691
# Epoch 27 Batch 2150 Loss 0.6072 Accuracy 0.7687
# Epoch 27 Batch 2200 Loss 0.6082 Accuracy 0.7685
# Epoch 27 Batch 2250 Loss 0.6087 Accuracy 0.7682
# Epoch 27 Batch 2300 Loss 0.6091 Accuracy 0.7679
# Epoch 27 Batch 2350 Loss 0.6092 Accuracy 0.7678
# Epoch 27 Batch 2400 Loss 0.6096 Accuracy 0.7679
# Epoch 27 Batch 2450 Loss 0.6099 Accuracy 0.7677
# Epoch 27 Batch 2500 Loss 0.6102 Accuracy 0.7676
# Epoch 27 Batch 2550 Loss 0.6105 Accuracy 0.7675
# Epoch 27 Batch 2600 Loss 0.6111 Accuracy 0.7673
# Epoch 27 Batch 2650 Loss 0.6119 Accuracy 0.7671
# Epoch 27 Batch 2700 Loss 0.6120 Accuracy 0.7669
# Epoch 27 Batch 2750 Loss 0.6124 Accuracy 0.7670
# Epoch 27 Batch 2800 Loss 0.6125 Accuracy 0.7669
# Epoch 27 Batch 2850 Loss 0.6129 Accuracy 0.7668
# Epoch 27 Batch 2900 Loss 0.6132 Accuracy 0.7668
# Epoch 27 Batch 2950 Loss 0.6132 Accuracy 0.7668
# Epoch 27 Batch 3000 Loss 0.6132 Accuracy 0.7667
# Epoch 27 Batch 3050 Loss 0.6136 Accuracy 0.7667
# Epoch 27 Batch 3100 Loss 0.6139 Accuracy 0.7666
# Epoch 27 Batch 3150 Loss 0.6143 Accuracy 0.7666
# Epoch 27 Batch 3200 Loss 0.6150 Accuracy 0.7664
# Epoch 27 Batch 3250 Loss 0.6151 Accuracy 0.7663
# Epoch 27 Batch 3300 Loss 0.6153 Accuracy 0.7663
# Epoch 27 Batch 3350 Loss 0.6160 Accuracy 0.7661
# Epoch 27 Batch 3400 Loss 0.6164 Accuracy 0.7660
# Epoch 27 Loss 0.6166 Accuracy 0.7659
# Time taken for 1 epoch: 73.77 secs
#
# Epoch 28 Batch 0 Loss 0.6092 Accuracy 0.7786
# Epoch 28 Batch 50 Loss 0.6138 Accuracy 0.7621
# Epoch 28 Batch 100 Loss 0.5963 Accuracy 0.7703
# Epoch 28 Batch 150 Loss 0.5950 Accuracy 0.7713
# Epoch 28 Batch 200 Loss 0.5893 Accuracy 0.7741
# Epoch 28 Batch 250 Loss 0.5888 Accuracy 0.7752
# Epoch 28 Batch 300 Loss 0.5883 Accuracy 0.7754
# Epoch 28 Batch 350 Loss 0.5876 Accuracy 0.7760
# Epoch 28 Batch 400 Loss 0.5864 Accuracy 0.7768
# Epoch 28 Batch 450 Loss 0.5864 Accuracy 0.7764
# Epoch 28 Batch 500 Loss 0.5884 Accuracy 0.7758
# Epoch 28 Batch 550 Loss 0.5899 Accuracy 0.7748
# Epoch 28 Batch 600 Loss 0.5898 Accuracy 0.7748
# Epoch 28 Batch 650 Loss 0.5904 Accuracy 0.7748
# Epoch 28 Batch 700 Loss 0.5907 Accuracy 0.7747
# Epoch 28 Batch 750 Loss 0.5921 Accuracy 0.7741
# Epoch 28 Batch 800 Loss 0.5930 Accuracy 0.7739
# Epoch 28 Batch 850 Loss 0.5937 Accuracy 0.7732
# Epoch 28 Batch 900 Loss 0.5943 Accuracy 0.7731
# Epoch 28 Batch 950 Loss 0.5943 Accuracy 0.7728
# Epoch 28 Batch 1000 Loss 0.5948 Accuracy 0.7723
# Epoch 28 Batch 1050 Loss 0.5950 Accuracy 0.7722
# Epoch 28 Batch 1100 Loss 0.5955 Accuracy 0.7723
# Epoch 28 Batch 1150 Loss 0.5959 Accuracy 0.7723
# Epoch 28 Batch 1200 Loss 0.5961 Accuracy 0.7723
# Epoch 28 Batch 1250 Loss 0.5960 Accuracy 0.7724
# Epoch 28 Batch 1300 Loss 0.5954 Accuracy 0.7725
# Epoch 28 Batch 1350 Loss 0.5951 Accuracy 0.7728
# Epoch 28 Batch 1400 Loss 0.5951 Accuracy 0.7728
# Epoch 28 Batch 1450 Loss 0.5949 Accuracy 0.7730
# Epoch 28 Batch 1500 Loss 0.5949 Accuracy 0.7728
# Epoch 28 Batch 1550 Loss 0.5954 Accuracy 0.7725
# Epoch 28 Batch 1600 Loss 0.5965 Accuracy 0.7720
# Epoch 28 Batch 1650 Loss 0.5971 Accuracy 0.7717
# Epoch 28 Batch 1700 Loss 0.5983 Accuracy 0.7712
# Epoch 28 Batch 1750 Loss 0.5993 Accuracy 0.7709
# Epoch 28 Batch 1800 Loss 0.6003 Accuracy 0.7707
# Epoch 28 Batch 1850 Loss 0.6011 Accuracy 0.7704
# Epoch 28 Batch 1900 Loss 0.6019 Accuracy 0.7702
# Epoch 28 Batch 1950 Loss 0.6029 Accuracy 0.7699
# Epoch 28 Batch 2000 Loss 0.6037 Accuracy 0.7698
# Epoch 28 Batch 2050 Loss 0.6048 Accuracy 0.7694
# Epoch 28 Batch 2100 Loss 0.6050 Accuracy 0.7693
# Epoch 28 Batch 2150 Loss 0.6050 Accuracy 0.7693
# Epoch 28 Batch 2200 Loss 0.6063 Accuracy 0.7690
# Epoch 28 Batch 2250 Loss 0.6065 Accuracy 0.7690
# Epoch 28 Batch 2300 Loss 0.6068 Accuracy 0.7688
# Epoch 28 Batch 2350 Loss 0.6072 Accuracy 0.7688
# Epoch 28 Batch 2400 Loss 0.6076 Accuracy 0.7687
# Epoch 28 Batch 2450 Loss 0.6082 Accuracy 0.7684
# Epoch 28 Batch 2500 Loss 0.6084 Accuracy 0.7683
# Epoch 28 Batch 2550 Loss 0.6085 Accuracy 0.7684
# Epoch 28 Batch 2600 Loss 0.6089 Accuracy 0.7682
# Epoch 28 Batch 2650 Loss 0.6094 Accuracy 0.7679
# Epoch 28 Batch 2700 Loss 0.6098 Accuracy 0.7677
# Epoch 28 Batch 2750 Loss 0.6107 Accuracy 0.7674
# Epoch 28 Batch 2800 Loss 0.6111 Accuracy 0.7673
# Epoch 28 Batch 2850 Loss 0.6111 Accuracy 0.7674
# Epoch 28 Batch 2900 Loss 0.6116 Accuracy 0.7672
# Epoch 28 Batch 2950 Loss 0.6121 Accuracy 0.7671
# Epoch 28 Batch 3000 Loss 0.6124 Accuracy 0.7670
# Epoch 28 Batch 3050 Loss 0.6125 Accuracy 0.7670
# Epoch 28 Batch 3100 Loss 0.6131 Accuracy 0.7669
# Epoch 28 Batch 3150 Loss 0.6131 Accuracy 0.7668
# Epoch 28 Batch 3200 Loss 0.6132 Accuracy 0.7667
# Epoch 28 Batch 3250 Loss 0.6138 Accuracy 0.7665
# Epoch 28 Batch 3300 Loss 0.6140 Accuracy 0.7665
# Epoch 28 Batch 3350 Loss 0.6143 Accuracy 0.7664
# Epoch 28 Batch 3400 Loss 0.6146 Accuracy 0.7663
# Epoch 28 Loss 0.6147 Accuracy 0.7663
# Time taken for 1 epoch: 73.83 secs
#
# Epoch 29 Batch 0 Loss 0.4548 Accuracy 0.8378
# Epoch 29 Batch 50 Loss 0.5870 Accuracy 0.7787
# Epoch 29 Batch 100 Loss 0.5878 Accuracy 0.7760
# Epoch 29 Batch 150 Loss 0.5856 Accuracy 0.7757
# Epoch 29 Batch 200 Loss 0.5836 Accuracy 0.7754
# Epoch 29 Batch 250 Loss 0.5863 Accuracy 0.7757
# Epoch 29 Batch 300 Loss 0.5866 Accuracy 0.7761
# Epoch 29 Batch 350 Loss 0.5847 Accuracy 0.7770
# Epoch 29 Batch 400 Loss 0.5846 Accuracy 0.7771
# Epoch 29 Batch 450 Loss 0.5867 Accuracy 0.7763
# Epoch 29 Batch 500 Loss 0.5870 Accuracy 0.7757
# Epoch 29 Batch 550 Loss 0.5869 Accuracy 0.7757
# Epoch 29 Batch 600 Loss 0.5871 Accuracy 0.7751
# Epoch 29 Batch 650 Loss 0.5864 Accuracy 0.7758
# Epoch 29 Batch 700 Loss 0.5872 Accuracy 0.7755
# Epoch 29 Batch 750 Loss 0.5889 Accuracy 0.7751
# Epoch 29 Batch 800 Loss 0.5893 Accuracy 0.7752
# Epoch 29 Batch 850 Loss 0.5892 Accuracy 0.7753
# Epoch 29 Batch 900 Loss 0.5895 Accuracy 0.7752
# Epoch 29 Batch 950 Loss 0.5907 Accuracy 0.7747
# Epoch 29 Batch 1000 Loss 0.5916 Accuracy 0.7739
# Epoch 29 Batch 1050 Loss 0.5922 Accuracy 0.7737
# Epoch 29 Batch 1100 Loss 0.5926 Accuracy 0.7735
# Epoch 29 Batch 1150 Loss 0.5931 Accuracy 0.7731
# Epoch 29 Batch 1200 Loss 0.5942 Accuracy 0.7727
# Epoch 29 Batch 1250 Loss 0.5940 Accuracy 0.7728
# Epoch 29 Batch 1300 Loss 0.5938 Accuracy 0.7731
# Epoch 29 Batch 1350 Loss 0.5937 Accuracy 0.7733
# Epoch 29 Batch 1400 Loss 0.5942 Accuracy 0.7731
# Epoch 29 Batch 1450 Loss 0.5946 Accuracy 0.7731
# Epoch 29 Batch 1500 Loss 0.5946 Accuracy 0.7731
# Epoch 29 Batch 1550 Loss 0.5949 Accuracy 0.7729
# Epoch 29 Batch 1600 Loss 0.5958 Accuracy 0.7725
# Epoch 29 Batch 1650 Loss 0.5969 Accuracy 0.7720
# Epoch 29 Batch 1700 Loss 0.5978 Accuracy 0.7715
# Epoch 29 Batch 1750 Loss 0.5982 Accuracy 0.7713
# Epoch 29 Batch 1800 Loss 0.5997 Accuracy 0.7711
# Epoch 29 Batch 1850 Loss 0.6003 Accuracy 0.7708
# Epoch 29 Batch 1900 Loss 0.6014 Accuracy 0.7705
# Epoch 29 Batch 1950 Loss 0.6019 Accuracy 0.7704
# Epoch 29 Batch 2000 Loss 0.6026 Accuracy 0.7702
# Epoch 29 Batch 2050 Loss 0.6035 Accuracy 0.7699
# Epoch 29 Batch 2100 Loss 0.6041 Accuracy 0.7697
# Epoch 29 Batch 2150 Loss 0.6047 Accuracy 0.7694
# Epoch 29 Batch 2200 Loss 0.6054 Accuracy 0.7692
# Epoch 29 Batch 2250 Loss 0.6061 Accuracy 0.7689
# Epoch 29 Batch 2300 Loss 0.6064 Accuracy 0.7687
# Epoch 29 Batch 2350 Loss 0.6065 Accuracy 0.7686
# Epoch 29 Batch 2400 Loss 0.6068 Accuracy 0.7685
# Epoch 29 Batch 2450 Loss 0.6077 Accuracy 0.7682
# Epoch 29 Batch 2500 Loss 0.6080 Accuracy 0.7680
# Epoch 29 Batch 2550 Loss 0.6081 Accuracy 0.7680
# Epoch 29 Batch 2600 Loss 0.6085 Accuracy 0.7678
# Epoch 29 Batch 2650 Loss 0.6090 Accuracy 0.7678
# Epoch 29 Batch 2700 Loss 0.6093 Accuracy 0.7676
# Epoch 29 Batch 2750 Loss 0.6099 Accuracy 0.7675
# Epoch 29 Batch 2800 Loss 0.6101 Accuracy 0.7674
# Epoch 29 Batch 2850 Loss 0.6103 Accuracy 0.7673
# Epoch 29 Batch 2900 Loss 0.6108 Accuracy 0.7670
# Epoch 29 Batch 2950 Loss 0.6115 Accuracy 0.7668
# Epoch 29 Batch 3000 Loss 0.6118 Accuracy 0.7667
# Epoch 29 Batch 3050 Loss 0.6120 Accuracy 0.7665
# Epoch 29 Batch 3100 Loss 0.6121 Accuracy 0.7665
# Epoch 29 Batch 3150 Loss 0.6124 Accuracy 0.7665
# Epoch 29 Batch 3200 Loss 0.6130 Accuracy 0.7663
# Epoch 29 Batch 3250 Loss 0.6131 Accuracy 0.7663
# Epoch 29 Batch 3300 Loss 0.6134 Accuracy 0.7663
# Epoch 29 Batch 3350 Loss 0.6135 Accuracy 0.7664
# Epoch 29 Batch 3400 Loss 0.6138 Accuracy 0.7663
# Epoch 29 Loss 0.6139 Accuracy 0.7662
# Time taken for 1 epoch: 73.98 secs
#
# Epoch 30 Batch 0 Loss 0.5999 Accuracy 0.7943
# Epoch 30 Batch 50 Loss 0.5778 Accuracy 0.7791
# Epoch 30 Batch 100 Loss 0.5801 Accuracy 0.7794
# Epoch 30 Batch 150 Loss 0.5770 Accuracy 0.7794
# Epoch 30 Batch 200 Loss 0.5781 Accuracy 0.7780
# Epoch 30 Batch 250 Loss 0.5795 Accuracy 0.7777
# Epoch 30 Batch 300 Loss 0.5830 Accuracy 0.7759
# Epoch 30 Batch 350 Loss 0.5845 Accuracy 0.7751
# Epoch 30 Batch 400 Loss 0.5854 Accuracy 0.7751
# Epoch 30 Batch 450 Loss 0.5832 Accuracy 0.7759
# Epoch 30 Batch 500 Loss 0.5829 Accuracy 0.7762
# Epoch 30 Batch 550 Loss 0.5837 Accuracy 0.7758
# Epoch 30 Batch 600 Loss 0.5852 Accuracy 0.7755
# Epoch 30 Batch 650 Loss 0.5869 Accuracy 0.7746
# Epoch 30 Batch 700 Loss 0.5881 Accuracy 0.7740
# Epoch 30 Batch 750 Loss 0.5889 Accuracy 0.7738
# Epoch 30 Batch 800 Loss 0.5887 Accuracy 0.7740
# Epoch 30 Batch 850 Loss 0.5874 Accuracy 0.7745
# Epoch 30 Batch 900 Loss 0.5878 Accuracy 0.7745
# Epoch 30 Batch 950 Loss 0.5893 Accuracy 0.7738
# Epoch 30 Batch 1000 Loss 0.5891 Accuracy 0.7739
# Epoch 30 Batch 1050 Loss 0.5900 Accuracy 0.7735
# Epoch 30 Batch 1100 Loss 0.5900 Accuracy 0.7734
# Epoch 30 Batch 1150 Loss 0.5904 Accuracy 0.7733
# Epoch 30 Batch 1200 Loss 0.5907 Accuracy 0.7730
# Epoch 30 Batch 1250 Loss 0.5908 Accuracy 0.7732
# Epoch 30 Batch 1300 Loss 0.5907 Accuracy 0.7735
# Epoch 30 Batch 1350 Loss 0.5907 Accuracy 0.7736
# Epoch 30 Batch 1400 Loss 0.5914 Accuracy 0.7733
# Epoch 30 Batch 1450 Loss 0.5913 Accuracy 0.7735
# Epoch 30 Batch 1500 Loss 0.5916 Accuracy 0.7733
# Epoch 30 Batch 1550 Loss 0.5925 Accuracy 0.7730
# Epoch 30 Batch 1600 Loss 0.5933 Accuracy 0.7726
# Epoch 30 Batch 1650 Loss 0.5941 Accuracy 0.7723
# Epoch 30 Batch 1700 Loss 0.5958 Accuracy 0.7718
# Epoch 30 Batch 1750 Loss 0.5972 Accuracy 0.7714
# Epoch 30 Batch 1800 Loss 0.5979 Accuracy 0.7710
# Epoch 30 Batch 1850 Loss 0.5988 Accuracy 0.7709
# Epoch 30 Batch 1900 Loss 0.6001 Accuracy 0.7707
# Epoch 30 Batch 1950 Loss 0.6011 Accuracy 0.7705
# Epoch 30 Batch 2000 Loss 0.6020 Accuracy 0.7701
# Epoch 30 Batch 2050 Loss 0.6030 Accuracy 0.7698
# Epoch 30 Batch 2100 Loss 0.6032 Accuracy 0.7697
# Epoch 30 Batch 2150 Loss 0.6040 Accuracy 0.7694
# Epoch 30 Batch 2200 Loss 0.6045 Accuracy 0.7691
# Epoch 30 Batch 2250 Loss 0.6051 Accuracy 0.7688
# Epoch 30 Batch 2300 Loss 0.6059 Accuracy 0.7686
# Epoch 30 Batch 2350 Loss 0.6066 Accuracy 0.7684
# Epoch 30 Batch 2400 Loss 0.6071 Accuracy 0.7683
# Epoch 30 Batch 2450 Loss 0.6070 Accuracy 0.7684
# Epoch 30 Batch 2500 Loss 0.6073 Accuracy 0.7683
# Epoch 30 Batch 2550 Loss 0.6077 Accuracy 0.7682
# Epoch 30 Batch 2600 Loss 0.6078 Accuracy 0.7683
# Epoch 30 Batch 2650 Loss 0.6081 Accuracy 0.7682
# Epoch 30 Batch 2700 Loss 0.6089 Accuracy 0.7680
# Epoch 30 Batch 2750 Loss 0.6091 Accuracy 0.7679
# Epoch 30 Batch 2800 Loss 0.6094 Accuracy 0.7678
# Epoch 30 Batch 2850 Loss 0.6101 Accuracy 0.7676
# Epoch 30 Batch 2900 Loss 0.6101 Accuracy 0.7676
# Epoch 30 Batch 2950 Loss 0.6104 Accuracy 0.7675
# Epoch 30 Batch 3000 Loss 0.6104 Accuracy 0.7675
# Epoch 30 Batch 3050 Loss 0.6107 Accuracy 0.7675
# Epoch 30 Batch 3100 Loss 0.6110 Accuracy 0.7674
# Epoch 30 Batch 3150 Loss 0.6112 Accuracy 0.7674
# Epoch 30 Batch 3200 Loss 0.6114 Accuracy 0.7673
# Epoch 30 Batch 3250 Loss 0.6117 Accuracy 0.7672
# Epoch 30 Batch 3300 Loss 0.6120 Accuracy 0.7671
# Epoch 30 Batch 3350 Loss 0.6125 Accuracy 0.7669
# Epoch 30 Batch 3400 Loss 0.6124 Accuracy 0.7669
# Saving checkpoint for epoch 30 at ./checkpoints/train4/ckpt-6
# Epoch 30 Loss 0.6126 Accuracy 0.7669
# Time taken for 1 epoch: 74.06 secs

# %% [markdown]
# ## Evaluation

# %%
#  evaluate the model single word
word = 'ذهب'
print(evaluate(word, alphabet_ar, alphabet_en, transformer))
df.loc[df['arabic']=='<'+word+'>']
# Out:
# <sab>
#       arabic english      arabic_encoded      english_encoded
# 32610  <ذهب>  <saab>  [1, 18, 36, 10, 2]  [1, 21, 3, 3, 4, 2]

# %%
#  read the test data of ANETAC dataset
df_ar = pd.read_csv('EN-AR Translit/test.ar',names=['arabic'],header=None)
df_en = pd.read_csv('EN-AR Translit/test.en',names=['english'],header=None)

df_test = pd.concat([df_ar,df_en],axis=1)

# %%
# Apply the model to the test data and remove the < and >
df_test['model']= df_test['arabic'].apply(lambda x:evaluate(x,alphabet_ar,alphabet_en,transformer))
df_test['model'] = df_test['model'].apply(lambda x:x.replace('<','').replace('>',''))

# %%
# Calaculate word error rate (WER) and character error rate (CER)
wers=[]
cers=[]
for _,row in df_test.iterrows():
  wers.append(wer(row['english'],row['model']))
  cers.append(cer(row['english'],row['model']))

df_test['wer'] = wers
df_test['cer'] = cers

df_test.to_excel('test3.xlsx')

print(df_test['wer'].mean())
print(df_test['cer'].mean())
# Out:
# 0.7770404777704047
# 0.22938223576909683

# %%
# to do 
# more data from Quran transliterations 
# tri input 
# hyperparamter tuning 
# include the tashkeel in the input vecb
